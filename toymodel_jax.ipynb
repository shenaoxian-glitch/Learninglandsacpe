# %%
import jax
import jax.numpy as jnp
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib import cm
import optax

PARAMS2 = {
    'a': -0.877,      
    'b': -1.2,    
    'c': 2.08,      
    'd': -1.4     
}

PARAMS = {
    'a': 0,      # Bifurcation point (y=0)
    'b': -1.6,   # x-scale stability, distance between branches^-1
    'c': 3.5,      # Drive strength (tilt), distance between bifurcation and new stable points
    'd': -1.2     # Wall steepness
}

# Simulation controls
N_PARTICLES = 1000
T_TOTAL = 1          # Total duration
dt = 0.005            # Time step size
n_steps = int(T_TOTAL / dt)
sigma = 1          # Noise
x0 = 0.0             # Initial x position (near the unstable point)
dx = 0.1            # Initial noise scale for x
y0 = -1.0            # Initial y position (before bifurcation)
dy = 0.1            # Initial noise scale for y

# --- JAX Random Setup & Initialization ---
# JAX requires explicit PRNG keys for reproducibility
key = jax.random.PRNGKey(4)
key, subkey_x, subkey_y = jax.random.split(key, 3)

# initialize particles using jax.random
particles_x = x0 + dx * jax.random.normal(subkey_x, (N_PARTICLES,))
particles_y = y0 + dy * jax.random.normal(subkey_y, (N_PARTICLES,))

def potential(x, y, p):
    """ H= -(y - a)x^2 + e^b x^4 - c y + e^d y^4 """
    return -(y - p['a']) * (x**2) + jnp.exp(p['b']) * (x**4) - p['c'] * y + jnp.exp(p['d']) * (y**4)

# --- JAX Autodiff ---
# jax.grad calculates derivatives w.r.t x (arg 0) and y (arg 1)
# jax.vmap vectorizes this calculation to handle arrays of particles
force_fn = jax.vmap(jax.grad(potential, argnums=(0, 1)), in_axes=(0, 0, None))

def force(x, y, p):
    """
    Fx = -dH/dx, Fy = -dH/dy
    Now calculated automatically via JAX autodiff!
    """
    grad_x, grad_y = force_fn(x, y, p)
    return -grad_x, -grad_y

# --- Plot Setup ---

# Using jnp.linspace; matplotlib handles JAX arrays seamlessly
x = jnp.linspace(-5, 5, 200)
y = jnp.linspace(-2, 4, 200)
X, Y = jnp.meshgrid(x, y)
Z = potential(X, Y, p=PARAMS)

# --- Plotting ---

fig = plt.figure(figsize=(10, 5))

# Subplot 1: 3D Surface Plot
ax1 = fig.add_subplot(1, 2, 1, projection='3d')
surf = ax1.plot_surface(X, Y, Z, cmap=cm.viridis, alpha=0.9, edgecolor='none')
ax1.set_title("2D Landscape", fontsize=14)
ax1.set_xlabel("x")
ax1.set_ylabel("y")
ax1.set_zlabel("$\phi$")
# Adjust view angle to see the branching clearly
ax1.view_init(elev=30, azim=160) 

# Subplot 2: Contour Plot (Top-down view)
ax2 = fig.add_subplot(1, 2, 2)
contour = ax2.contourf(X, Y, Z, levels=30, cmap=cm.viridis)
ax2.set_title("Top View", fontsize=14)
ax2.set_xlabel("x")
ax2.set_ylabel("y")

plt.tight_layout()
plt.show()

# --- Run Simulation (Euler-Maruyama) ---

# We isolate the physics update into a function so jax can JIT compile it
@jax.jit
def update_step(px, py, step_key, params, dt_val, sigma_val):
    # Calculate deterministic force (Drift)
    fx, fy = force(px, py, params)
    
    # Generate random noise (Diffusion)
    # Scale by sqrt(dt) strictly according to SDE theory
    key_x, key_y = jax.random.split(step_key)
    noise_x = jax.random.normal(key_x, px.shape) * jnp.sqrt(dt_val)
    noise_y = jax.random.normal(key_y, py.shape) * jnp.sqrt(dt_val)
    
    # Update positions (Note: JAX arrays are immutable, so we return new ones)
    new_px = px + fx * dt_val + sigma_val * noise_x
    new_py = py + fy * dt_val + sigma_val * noise_y
    
    return new_px, new_py

print(f"Simulating {N_PARTICLES} particles for {n_steps} steps...")

for step in range(n_steps):
    # Split the key at every step to ensure completely new random noise
    key, step_key = jax.random.split(key)
    particles_x, particles_y = update_step(particles_x, particles_y, step_key, PARAMS, dt, sigma)

# --- Visualization ---

plt.figure(figsize=(8, 6))

# Plot the Landscape Contour
contour = plt.contourf(X, Y, Z, levels=25, cmap='viridis', alpha=0.6)
plt.colorbar(contour, label='Potential($\phi$)')

# Plot the Particles
plt.scatter(particles_x, particles_y, color='red', s=15, alpha=0.7, edgecolors='black', label='Particles')

# Mark the bifurcation line
plt.axhline(PARAMS['a'], color='white', linestyle='--', label='Bifurcation (y=0)')

plt.title(f"Particle Distribution at T={T_TOTAL} (Sigma={sigma})")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Simulating 1000 particles for 200 steps...

# %%
import ipywidgets as widgets  # Import the Jupyter-native widgets
from IPython.display import display

# --- Initialization (JAX style) ---
# Assuming 'key' is carried over from Part 1. We split it to get fresh randomness.
key, subkey_x, subkey_y, scan_key = jax.random.split(key, 4)

p_x = x0 + dx * jax.random.normal(subkey_x, (N_PARTICLES,))
p_y = y0 + dy * jax.random.normal(subkey_y, (N_PARTICLES,))


# --- JAX lax.scan for history generation ---
# Instead of a Python for loop and np.zeros arrays, we use jax.lax.scan.
# It carries the state forward and automatically accumulates the history.

@jax.jit
def scan_step(carry, step_key):
    """
    carry: A tuple of the current state (px, py)
    step_key: A unique random key for this specific time step
    """
    px, py = carry
    
    # Calculate deterministic force (Drift)
    fx, fy = force(px, py, PARAMS)
    
    # Generate random noise (Diffusion)
    key_x, key_y = jax.random.split(step_key)
    noise_x = jax.random.normal(key_x, px.shape) * jnp.sqrt(dt)
    noise_y = jax.random.normal(key_y, py.shape) * jnp.sqrt(dt)
    
    # Update positions
    new_px = px + fx * dt + sigma * noise_x
    new_py = py + fy * dt + sigma * noise_y
    
    # Return (new_carry_state, output_to_save_to_history)
    # We save the *current* px, py to history, and carry the *new* px, py forward
    return (new_px, new_py), (px, py)

# Generate an array of unique keys for each step in the loop
step_keys = jax.random.split(scan_key, n_steps)

# Run the compiled scan loop
# history will be a tuple of (history_x, history_y), automatically stacked along a new time dimension
_, (history_x, history_y) = jax.lax.scan(scan_step, (p_x, p_y), step_keys)


# --- Visualization with Interactive Slider ---

def plot_frame(step_index):
    
    # Create a figure
    fig, ax = plt.subplots(figsize=(8, 8))
    
    # Plot Background
    ax.contourf(X, Y, Z, levels=25, cmap='viridis', alpha=0.6)
    ax.axhline(PARAMS['a'], color='white', linestyle='--', alpha=0.5, label='Bifurcation')
    
    # Plot Particles
    current_x = history_x[step_index]
    current_y = history_y[step_index]
    ax.scatter(current_x, current_y, c='red', s=15, edgecolors='black', alpha=0.8)
    
    # Labels
    ax.set_title(f"Time: {step_index * dt:.2f} / {T_TOTAL:.2f}")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    
    plt.show() 

# 1. Create the interactive widget object
ui = widgets.interactive(
    plot_frame, 
    step_index=widgets.IntSlider(
        min=0, 
        max=n_steps-1, 
        step=5,           
        value=0, 
        description='Time Step',
        continuous_update=False # Prevents lagging while dragging
    )
)

# 2. Display the UI object explicitly
display(ui)
# Out:
# interactive(children=(IntSlider(value=0, continuous_update=False, description='Time Step', max=199, step=5), O…

# %%
# MMD Parameter Inference

# 1. Generate Fake "Real Cell Data" (Target)
target_params = PARAMS.copy()

# Create a master key for inference
infer_key = jax.random.PRNGKey(23)
infer_key, target_key = jax.random.split(infer_key)

def get_sim_data_jax(params, key, steps):
    # Setup initial positions
    k1, k2, scan_key = jax.random.split(key, 3)
    px = x0 + dx * jax.random.normal(k1, (N_PARTICLES,))
    py = y0 + dy * jax.random.normal(k2, (N_PARTICLES,))
    
    # We use scan but only care about the final state, so we discard history
    def step_fn(carry, step_key):
        curr_px, curr_py = carry
        # force is the JAX-vmap-grad function from Part 1
        fx, fy = force(curr_px, curr_py, params)
        
        kx, ky = jax.random.split(step_key)
        n_x = jax.random.normal(kx, curr_px.shape) * jnp.sqrt(dt)
        n_y = jax.random.normal(ky, curr_py.shape) * jnp.sqrt(dt)
        
        new_px = curr_px + fx * dt + sigma * n_x
        new_py = curr_py + fy * dt + sigma * n_y
        
        # Return new state as carry, None for history
        return (new_px, new_py), None
        
    step_keys = jax.random.split(scan_key, steps)
    final_state, _ = jax.lax.scan(step_fn, (px, py), step_keys)
    
    # Stack into Shape: (N, 2)
    return jnp.column_stack(final_state)

# We pass the function as the first argument, and set the 3rd argument (index 2) as static.
get_sim_data_jax = jax.jit(get_sim_data_jax, static_argnums=(2,))

# Generate Target Data
target_data = get_sim_data_jax(target_params, target_key, n_steps)


# 2. Compact MMD Loss Function (multiple bandwidths for stability)
@jax.jit
def mmd_loss(x1, x2):
    """
    Calculates MMD squared: E[K(x,x)] + E[K(y,y)] - 2E[K(x,y)]
    """
    def k_mean(a, b):
        # 1. Expand dims for broadcasting: (N, 1, 2) - (1, M, 2)
        diff = a[:, None, :] - b[None, :, :]
        # 2. Squared Euclidean distance
        dist_sq = jnp.sum(diff**2, axis=-1)
        # 3. Gaussian Kernel & Mean
        return jnp.exp(-dist_sq / (2*0.01)).mean()+jnp.exp(-dist_sq / (2*1)).mean()+jnp.exp(-dist_sq / (2*100)).mean()

    # MMD Formula
    return k_mean(x1, x1) + k_mean(x2, x2) - 2 * k_mean(x1, x2)


# 2b. Wasserstein Distance (Sliced) Loss Function
@jax.jit
def wasserstein_loss(x1, x2):
    """
    Calculates Sliced Wasserstein Distance between two point clouds.
    Uses random projections to approximate the full Wasserstein distance efficiently.
    """
    n_projections = 50
    rng_key = jax.random.PRNGKey(0)
    
    def single_projection_distance(key):
        # Generate random direction on unit circle
        theta = jax.random.uniform(key, minval=0, maxval=2*jnp.pi)
        direction = jnp.array([jnp.cos(theta), jnp.sin(theta)])
        
        # Project both point clouds onto this direction
        proj_x1 = jnp.dot(x1, direction)
        proj_x2 = jnp.dot(x2, direction)
        
        # Sort projections
        proj_x1_sorted = jnp.sort(proj_x1)
        proj_x2_sorted = jnp.sort(proj_x2)
        
        # Compute 1D Wasserstein distance (L2 between sorted points)
        return jnp.mean((proj_x1_sorted - proj_x2_sorted) ** 2)
    
    # Average over random projections
    keys = jax.random.split(rng_key, n_projections)
    distances = jax.vmap(single_projection_distance)(keys)
    
    return jnp.mean(distances)


# 3. Objective Function for Automatic Differentiation

def objective(params, fixed_params, target, key):
    """
    This function isolates what we want to optimize (params) 
    from what remains constant (fixed_params).
    """
    # Merge parameters for the simulation
    full_params = {**fixed_params, **params}
    
    # Run simulation
    sim_data = get_sim_data_jax(full_params, key, n_steps)
    
    # Calculate MMD loss against target
    return mmd_loss(sim_data, target)

# This creates a function that computes both the loss and the gradients 
loss_and_grad_fn = jax.jit(jax.value_and_grad(objective, argnums=0))


# 4. Run Gradient Descent

# We separate the parameters we want to learn from the fixed ones.
# Ensure initial values are floats.
current_params = {'a': 0.9, 'b': -1.2, 'c': 2.1, 'd': -1.4} 
fixed_params = {}

# %%
# Learning Rate
lr_a = 1
lr_b = 1
lr_c = 3
lr_d = 1

print(f"Target a: {target_params['a']}, Start a: {current_params['a']}")
print(f"Target b: {target_params['b']}, Start b: {current_params['b']}")
print(f"Target c: {target_params['c']}, Start c: {current_params['c']}")
print(f"Target d: {target_params['d']}, Start d: {current_params['d']}")

# use a fixed seed for the optimization forward passes so the gradients are not overwhelmed by noise
opt_key = jax.random.PRNGKey(49)

for i in range(500): 
    
    # 1. Get Loss and EXACT Gradients in one step
    loss, grads = loss_and_grad_fn(current_params, fixed_params, target_data, opt_key)
    
    # Extract gradients 
    # JAX returns a dictionary of gradients with exactly the same keys as current_params
    grad_a = grads['a']
    grad_b = grads['b']
    grad_c = grads['c']
    grad_d = grads['d']
    
    # 2. Update
    current_params['a'] -= lr_a * grad_a
    current_params['b'] -= lr_b * grad_b
    current_params['c'] -= lr_c * grad_c
    current_params['d'] -= lr_d * grad_d

    # Apply physical constraints(no restriction on a; restriction on b should be tuned carefully 
    # if b is too small, particles will not be restricted enough and can diverge to infinity)
    if current_params['c'] < 0.001:
        current_params['c'] = 0.001

    # Cutoff condition
    if loss < 0.0001:
        break
    
    print(f"Iter {i}: Loss={loss:.5f}")
    print(f"    Grad a={grad_a:.4f} -> Update a to {current_params['a']:.3f}")
    print(f"    Grad b={grad_b:.4f} -> Update b to {current_params['b']:.3f}")
    print(f"    Grad c={grad_c:.4f} -> Update c to {current_params['c']:.3f}")
    print(f"    Grad d={grad_d:.4f} -> Update d to {current_params['d']:.3f}")

print(f"Final Estimated a: {current_params['a']:.3f} (True: {target_params['a']})")
print(f"Final Estimated b: {current_params['b']:.3f} (True: {target_params['b']})")
print(f"Final Estimated c: {current_params['c']:.3f} (True: {target_params['c']})")
print(f"Final Estimated d: {current_params['d']:.3f} (True: {target_params['d']})")
# Out:
# Target a: 0, Start a: 0.9
# Target b: -1.6, Start b: -1.2
# Target c: 3.5, Start c: 2.1
# Target d: -1.2, Start d: -1.4
# Iter 0: Loss=0.21637
#     Grad a=0.1402 -> Update a to 0.760
#     Grad b=0.0598 -> Update b to -1.260
#     Grad c=-0.1322 -> Update c to 2.497
#     Grad d=0.0957 -> Update d to -1.496
# Iter 1: Loss=0.13899
#     Grad a=0.1569 -> Update a to 0.603
#     Grad b=0.0730 -> Update b to -1.333
#     Grad c=-0.0877 -> Update c to 2.760
#     Grad d=0.0834 -> Update d to -1.579
# Iter 2: Loss=0.08334
#     Grad a=0.1562 -> Update a to 0.447
#     Grad b=0.0779 -> Update b to -1.411
#     Grad c=-0.0583 -> Update c to 2.935
#     Grad d=0.0569 -> Update d to -1.636
# Iter 3: Loss=0.04440
#     Grad a=0.1313 -> Update a to 0.315
#     Grad b=0.0682 -> Update b to -1.479
#     Grad c=-0.0319 -> Update c to 3.030
#     Grad d=0.0227 -> Update d to -1.659
# Iter 4: Loss=0.02336
#     Grad a=0.0906 -> Update a to 0.225
#     Grad b=0.0488 -> Update b to -1.528
#     Grad c=-0.0107 -> Update c to 3.062
#     Grad d=-0.0054 -> Update d to -1.653
# Iter 5: Loss=0.01447
#     Grad a=0.0565 -> Update a to 0.168
#     Grad b=0.0301 -> Update b to -1.558
#     Grad c=0.0009 -> Update c to 3.060
#     Grad d=-0.0212 -> Update d to -1.632
# Iter 6: Loss=0.01059
#     Grad a=0.0371 -> Update a to 0.131
#     Grad b=0.0185 -> Update b to -1.576
#     Grad c=0.0046 -> Update c to 3.046
#     Grad d=-0.0257 -> Update d to -1.607
# Iter 7: Loss=0.00839
#     Grad a=0.0274 -> Update a to 0.104
#     Grad b=0.0122 -> Update b to -1.589
#     Grad c=0.0045 -> Update c to 3.032
#     Grad d=-0.0252 -> Update d to -1.581
# Iter 8: Loss=0.00694
#     Grad a=0.0208 -> Update a to 0.083
#     Grad b=0.0079 -> Update b to -1.596
#     Grad c=0.0037 -> Update c to 3.021
#     Grad d=-0.0235 -> Update d to -1.558
# Iter 9: Loss=0.00594
#     Grad a=0.0163 -> Update a to 0.067
#     Grad b=0.0050 -> Update b to -1.601
#     Grad c=0.0026 -> Update c to 3.013
#     Grad d=-0.0213 -> Update d to -1.537
# Iter 10: Loss=0.00523
#     Grad a=0.0131 -> Update a to 0.054
#     Grad b=0.0029 -> Update b to -1.604
#     Grad c=0.0015 -> Update c to 3.009
#     Grad d=-0.0192 -> Update d to -1.517
# Iter 11: Loss=0.00472
#     Grad a=0.0107 -> Update a to 0.043
#     Grad b=0.0014 -> Update b to -1.606
#     Grad c=0.0006 -> Update c to 3.007
#     Grad d=-0.0172 -> Update d to -1.500
# Iter 12: Loss=0.00433
#     Grad a=0.0088 -> Update a to 0.034
#     Grad b=0.0003 -> Update b to -1.606
#     Grad c=-0.0001 -> Update c to 3.007
#     Grad d=-0.0155 -> Update d to -1.485
# Iter 13: Loss=0.00403
#     Grad a=0.0073 -> Update a to 0.027
#     Grad b=-0.0005 -> Update b to -1.606
#     Grad c=-0.0007 -> Update c to 3.009
#     Grad d=-0.0139 -> Update d to -1.471
# Iter 14: Loss=0.00380
#     Grad a=0.0061 -> Update a to 0.021
#     Grad b=-0.0011 -> Update b to -1.604
#     Grad c=-0.0011 -> Update c to 3.012
#     Grad d=-0.0125 -> Update d to -1.458
# Iter 15: Loss=0.00361
#     Grad a=0.0051 -> Update a to 0.016
#     Grad b=-0.0015 -> Update b to -1.603
#     Grad c=-0.0014 -> Update c to 3.017
#     Grad d=-0.0113 -> Update d to -1.447
# Iter 16: Loss=0.00345
#     Grad a=0.0044 -> Update a to 0.011
#     Grad b=-0.0017 -> Update b to -1.601
#     Grad c=-0.0017 -> Update c to 3.022
#     Grad d=-0.0102 -> Update d to -1.437
# Iter 17: Loss=0.00332
#     Grad a=0.0037 -> Update a to 0.008
#     Grad b=-0.0019 -> Update b to -1.599
#     Grad c=-0.0019 -> Update c to 3.027
#     Grad d=-0.0093 -> Update d to -1.427
# Iter 18: Loss=0.00321
#     Grad a=0.0032 -> Update a to 0.004
#     Grad b=-0.0020 -> Update b to -1.597
#     Grad c=-0.0020 -> Update c to 3.033
#     Grad d=-0.0085 -> Update d to -1.419
# Iter 19: Loss=0.00312
#     Grad a=0.0027 -> Update a to 0.002
#     Grad b=-0.0020 -> Update b to -1.595
#     Grad c=-0.0020 -> Update c to 3.039
#     Grad d=-0.0077 -> Update d to -1.411
# Iter 20: Loss=0.00304
#     Grad a=0.0024 -> Update a to -0.001
#     Grad b=-0.0020 -> Update b to -1.593
#     Grad c=-0.0020 -> Update c to 3.045
#     Grad d=-0.0071 -> Update d to -1.404
# Iter 21: Loss=0.00297
#     Grad a=0.0020 -> Update a to -0.003
#     Grad b=-0.0020 -> Update b to -1.591
#     Grad c=-0.0020 -> Update c to 3.052
#     Grad d=-0.0065 -> Update d to -1.398
# Iter 22: Loss=0.00291
#     Grad a=0.0018 -> Update a to -0.005
#     Grad b=-0.0020 -> Update b to -1.589
#     Grad c=-0.0020 -> Update c to 3.058
#     Grad d=-0.0060 -> Update d to -1.392
# Iter 23: Loss=0.00286
#     Grad a=0.0015 -> Update a to -0.006
#     Grad b=-0.0019 -> Update b to -1.587
#     Grad c=-0.0020 -> Update c to 3.064
#     Grad d=-0.0055 -> Update d to -1.386
# Iter 24: Loss=0.00281
#     Grad a=0.0013 -> Update a to -0.007
#     Grad b=-0.0018 -> Update b to -1.586
#     Grad c=-0.0019 -> Update c to 3.069
#     Grad d=-0.0051 -> Update d to -1.381
# Iter 25: Loss=0.00277
#     Grad a=0.0012 -> Update a to -0.009
#     Grad b=-0.0017 -> Update b to -1.584
#     Grad c=-0.0019 -> Update c to 3.075
#     Grad d=-0.0047 -> Update d to -1.376
# Iter 26: Loss=0.00273
#     Grad a=0.0010 -> Update a to -0.010
#     Grad b=-0.0016 -> Update b to -1.582
#     Grad c=-0.0018 -> Update c to 3.081
#     Grad d=-0.0044 -> Update d to -1.372
# Iter 27: Loss=0.00270
#     Grad a=0.0009 -> Update a to -0.010
#     Grad b=-0.0015 -> Update b to -1.581
#     Grad c=-0.0018 -> Update c to 3.086
#     Grad d=-0.0041 -> Update d to -1.368
# Iter 28: Loss=0.00267
#     Grad a=0.0008 -> Update a to -0.011
#     Grad b=-0.0014 -> Update b to -1.579
#     Grad c=-0.0017 -> Update c to 3.091
#     Grad d=-0.0038 -> Update d to -1.364
# Iter 29: Loss=0.00265
#     Grad a=0.0007 -> Update a to -0.012
#     Grad b=-0.0013 -> Update b to -1.578
#     Grad c=-0.0017 -> Update c to 3.096
#     Grad d=-0.0036 -> Update d to -1.360
# Iter 30: Loss=0.00262
#     Grad a=0.0006 -> Update a to -0.012
#     Grad b=-0.0012 -> Update b to -1.577
#     Grad c=-0.0016 -> Update c to 3.101
#     Grad d=-0.0034 -> Update d to -1.357
# Iter 31: Loss=0.00260
#     Grad a=0.0005 -> Update a to -0.013
#     Grad b=-0.0011 -> Update b to -1.576
#     Grad c=-0.0015 -> Update c to 3.105
#     Grad d=-0.0032 -> Update d to -1.354
# Iter 32: Loss=0.00259
#     Grad a=0.0004 -> Update a to -0.013
#     Grad b=-0.0011 -> Update b to -1.575
#     Grad c=-0.0015 -> Update c to 3.110
#     Grad d=-0.0030 -> Update d to -1.351
# Iter 33: Loss=0.00257
#     Grad a=0.0004 -> Update a to -0.014
#     Grad b=-0.0010 -> Update b to -1.574
#     Grad c=-0.0014 -> Update c to 3.114
#     Grad d=-0.0028 -> Update d to -1.348
# Iter 34: Loss=0.00256
#     Grad a=0.0003 -> Update a to -0.014
#     Grad b=-0.0009 -> Update b to -1.573
#     Grad c=-0.0014 -> Update c to 3.118
#     Grad d=-0.0027 -> Update d to -1.345
# Iter 35: Loss=0.00254
#     Grad a=0.0003 -> Update a to -0.014
#     Grad b=-0.0008 -> Update b to -1.572
#     Grad c=-0.0013 -> Update c to 3.122
#     Grad d=-0.0025 -> Update d to -1.343
# Iter 36: Loss=0.00253
#     Grad a=0.0002 -> Update a to -0.015
#     Grad b=-0.0007 -> Update b to -1.571
#     Grad c=-0.0013 -> Update c to 3.126
#     Grad d=-0.0024 -> Update d to -1.341
# Iter 37: Loss=0.00252
#     Grad a=0.0002 -> Update a to -0.015
#     Grad b=-0.0007 -> Update b to -1.570
#     Grad c=-0.0012 -> Update c to 3.130
#     Grad d=-0.0023 -> Update d to -1.338
# Iter 38: Loss=0.00251
#     Grad a=0.0001 -> Update a to -0.015
#     Grad b=-0.0006 -> Update b to -1.570
#     Grad c=-0.0012 -> Update c to 3.133
#     Grad d=-0.0021 -> Update d to -1.336
# Iter 39: Loss=0.00250
#     Grad a=0.0001 -> Update a to -0.015
#     Grad b=-0.0006 -> Update b to -1.569
#     Grad c=-0.0011 -> Update c to 3.136
#     Grad d=-0.0020 -> Update d to -1.334
# Iter 40: Loss=0.00249
#     Grad a=0.0001 -> Update a to -0.015
#     Grad b=-0.0005 -> Update b to -1.569
#     Grad c=-0.0011 -> Update c to 3.140
#     Grad d=-0.0019 -> Update d to -1.332
# Iter 41: Loss=0.00249
#     Grad a=0.0000 -> Update a to -0.015
#     Grad b=-0.0004 -> Update b to -1.568
#     Grad c=-0.0010 -> Update c to 3.143
#     Grad d=-0.0018 -> Update d to -1.330
# Iter 42: Loss=0.00248
#     Grad a=0.0000 -> Update a to -0.015
#     Grad b=-0.0004 -> Update b to -1.568
#     Grad c=-0.0010 -> Update c to 3.146
#     Grad d=-0.0018 -> Update d to -1.329
# Iter 43: Loss=0.00247
#     Grad a=-0.0000 -> Update a to -0.015
#     Grad b=-0.0003 -> Update b to -1.568
#     Grad c=-0.0010 -> Update c to 3.149
#     Grad d=-0.0017 -> Update d to -1.327
# Iter 44: Loss=0.00247
#     Grad a=-0.0000 -> Update a to -0.015
#     Grad b=-0.0003 -> Update b to -1.567
#     Grad c=-0.0009 -> Update c to 3.151
#     Grad d=-0.0016 -> Update d to -1.325
# Iter 45: Loss=0.00246
#     Grad a=-0.0001 -> Update a to -0.015
#     Grad b=-0.0003 -> Update b to -1.567
#     Grad c=-0.0009 -> Update c to 3.154
#     Grad d=-0.0015 -> Update d to -1.324
# Iter 46: Loss=0.00246
#     Grad a=-0.0001 -> Update a to -0.015
#     Grad b=-0.0002 -> Update b to -1.567
#     Grad c=-0.0009 -> Update c to 3.157
#     Grad d=-0.0015 -> Update d to -1.322
# Iter 47: Loss=0.00245
#     Grad a=-0.0001 -> Update a to -0.015
#     Grad b=-0.0002 -> Update b to -1.567
#     Grad c=-0.0008 -> Update c to 3.159
#     Grad d=-0.0014 -> Update d to -1.321
# Iter 48: Loss=0.00245
#     Grad a=-0.0001 -> Update a to -0.015
#     Grad b=-0.0001 -> Update b to -1.567
#     Grad c=-0.0008 -> Update c to 3.161
#     Grad d=-0.0013 -> Update d to -1.320
# Iter 49: Loss=0.00244
#     Grad a=-0.0001 -> Update a to -0.015
#     Grad b=-0.0001 -> Update b to -1.566
#     Grad c=-0.0008 -> Update c to 3.164
#     Grad d=-0.0013 -> Update d to -1.318
# Iter 50: Loss=0.00244
#     Grad a=-0.0001 -> Update a to -0.014
#     Grad b=-0.0001 -> Update b to -1.566
#     Grad c=-0.0007 -> Update c to 3.166
#     Grad d=-0.0012 -> Update d to -1.317
# Iter 51: Loss=0.00244
#     Grad a=-0.0002 -> Update a to -0.014
#     Grad b=-0.0001 -> Update b to -1.566
#     Grad c=-0.0007 -> Update c to 3.168
#     Grad d=-0.0012 -> Update d to -1.316
# Iter 52: Loss=0.00244
#     Grad a=-0.0002 -> Update a to -0.014
#     Grad b=-0.0000 -> Update b to -1.566
#     Grad c=-0.0007 -> Update c to 3.170
#     Grad d=-0.0011 -> Update d to -1.315
# Iter 53: Loss=0.00243
#     Grad a=-0.0002 -> Update a to -0.014
#     Grad b=0.0000 -> Update b to -1.566
#     Grad c=-0.0007 -> Update c to 3.172
#     Grad d=-0.0011 -> Update d to -1.314
# Iter 54: Loss=0.00243
#     Grad a=-0.0002 -> Update a to -0.014
#     Grad b=0.0000 -> Update b to -1.566
#     Grad c=-0.0006 -> Update c to 3.174
#     Grad d=-0.0010 -> Update d to -1.313
# Iter 55: Loss=0.00243
#     Grad a=-0.0002 -> Update a to -0.014
#     Grad b=0.0000 -> Update b to -1.566
#     Grad c=-0.0006 -> Update c to 3.176
#     Grad d=-0.0010 -> Update d to -1.312
# Iter 56: Loss=0.00243
#     Grad a=-0.0002 -> Update a to -0.013
#     Grad b=0.0001 -> Update b to -1.566
#     Grad c=-0.0006 -> Update c to 3.178
#     Grad d=-0.0010 -> Update d to -1.311
# Iter 57: Loss=0.00242
#     Grad a=-0.0002 -> Update a to -0.013
#     Grad b=0.0001 -> Update b to -1.566
#     Grad c=-0.0006 -> Update c to 3.179
#     Grad d=-0.0009 -> Update d to -1.310
# Iter 58: Loss=0.00242
#     Grad a=-0.0002 -> Update a to -0.013
#     Grad b=0.0001 -> Update b to -1.567
#     Grad c=-0.0006 -> Update c to 3.181
#     Grad d=-0.0009 -> Update d to -1.309
# Iter 59: Loss=0.00242
#     Grad a=-0.0002 -> Update a to -0.013
#     Grad b=0.0001 -> Update b to -1.567
#     Grad c=-0.0005 -> Update c to 3.183
#     Grad d=-0.0009 -> Update d to -1.308
# Iter 60: Loss=0.00242
#     Grad a=-0.0002 -> Update a to -0.012
#     Grad b=0.0001 -> Update b to -1.567
#     Grad c=-0.0005 -> Update c to 3.184
#     Grad d=-0.0008 -> Update d to -1.307
# Iter 61: Loss=0.00242
#     Grad a=-0.0002 -> Update a to -0.012
#     Grad b=0.0002 -> Update b to -1.567
#     Grad c=-0.0005 -> Update c to 3.186
#     Grad d=-0.0008 -> Update d to -1.306
# Iter 62: Loss=0.00242
#     Grad a=-0.0002 -> Update a to -0.012
#     Grad b=0.0002 -> Update b to -1.567
#     Grad c=-0.0005 -> Update c to 3.187
#     Grad d=-0.0008 -> Update d to -1.306
# Iter 63: Loss=0.00241
#     Grad a=-0.0003 -> Update a to -0.012
#     Grad b=0.0002 -> Update b to -1.567
#     Grad c=-0.0005 -> Update c to 3.189
#     Grad d=-0.0008 -> Update d to -1.305
# Iter 64: Loss=0.00241
#     Grad a=-0.0003 -> Update a to -0.011
#     Grad b=0.0002 -> Update b to -1.568
#     Grad c=-0.0005 -> Update c to 3.190
#     Grad d=-0.0007 -> Update d to -1.304
# Iter 65: Loss=0.00241
#     Grad a=-0.0003 -> Update a to -0.011
#     Grad b=0.0002 -> Update b to -1.568
#     Grad c=-0.0005 -> Update c to 3.191
#     Grad d=-0.0007 -> Update d to -1.303
# Iter 66: Loss=0.00241
#     Grad a=-0.0003 -> Update a to -0.011
#     Grad b=0.0002 -> Update b to -1.568
#     Grad c=-0.0004 -> Update c to 3.193
#     Grad d=-0.0007 -> Update d to -1.303
# Iter 67: Loss=0.00241
#     Grad a=-0.0003 -> Update a to -0.011
#     Grad b=0.0002 -> Update b to -1.568
#     Grad c=-0.0004 -> Update c to 3.194
#     Grad d=-0.0007 -> Update d to -1.302
# Iter 68: Loss=0.00241
#     Grad a=-0.0003 -> Update a to -0.010
#     Grad b=0.0002 -> Update b to -1.568
#     Grad c=-0.0004 -> Update c to 3.195
#     Grad d=-0.0006 -> Update d to -1.301
# Iter 69: Loss=0.00241
#     Grad a=-0.0003 -> Update a to -0.010
#     Grad b=0.0002 -> Update b to -1.569
#     Grad c=-0.0004 -> Update c to 3.196
#     Grad d=-0.0006 -> Update d to -1.301
# Iter 70: Loss=0.00241
#     Grad a=-0.0003 -> Update a to -0.010
#     Grad b=0.0003 -> Update b to -1.569
#     Grad c=-0.0004 -> Update c to 3.198
#     Grad d=-0.0006 -> Update d to -1.300
# Iter 71: Loss=0.00241
#     Grad a=-0.0003 -> Update a to -0.010
#     Grad b=0.0003 -> Update b to -1.569
#     Grad c=-0.0004 -> Update c to 3.199
#     Grad d=-0.0006 -> Update d to -1.300
# Iter 72: Loss=0.00240
#     Grad a=-0.0003 -> Update a to -0.009
#     Grad b=0.0003 -> Update b to -1.569
#     Grad c=-0.0004 -> Update c to 3.200
#     Grad d=-0.0006 -> Update d to -1.299
# Iter 73: Loss=0.00240
#     Grad a=-0.0003 -> Update a to -0.009
#     Grad b=0.0003 -> Update b to -1.570
#     Grad c=-0.0004 -> Update c to 3.201
#     Grad d=-0.0005 -> Update d to -1.298
# Iter 74: Loss=0.00240
#     Grad a=-0.0003 -> Update a to -0.009
#     Grad b=0.0003 -> Update b to -1.570
#     Grad c=-0.0004 -> Update c to 3.202
#     Grad d=-0.0005 -> Update d to -1.298
# Iter 75: Loss=0.00240
#     Grad a=-0.0003 -> Update a to -0.008
#     Grad b=0.0003 -> Update b to -1.570
#     Grad c=-0.0003 -> Update c to 3.203
#     Grad d=-0.0005 -> Update d to -1.297
# Iter 76: Loss=0.00240
#     Grad a=-0.0003 -> Update a to -0.008
#     Grad b=0.0003 -> Update b to -1.571
#     Grad c=-0.0003 -> Update c to 3.204
#     Grad d=-0.0005 -> Update d to -1.297
# Iter 77: Loss=0.00240
#     Grad a=-0.0003 -> Update a to -0.008
#     Grad b=0.0003 -> Update b to -1.571
#     Grad c=-0.0003 -> Update c to 3.205
#     Grad d=-0.0005 -> Update d to -1.296
# Iter 78: Loss=0.00240
#     Grad a=-0.0003 -> Update a to -0.008
#     Grad b=0.0003 -> Update b to -1.571
#     Grad c=-0.0003 -> Update c to 3.206
#     Grad d=-0.0005 -> Update d to -1.296
# Iter 79: Loss=0.00240
#     Grad a=-0.0003 -> Update a to -0.007
#     Grad b=0.0003 -> Update b to -1.572
#     Grad c=-0.0003 -> Update c to 3.207
#     Grad d=-0.0005 -> Update d to -1.296
# Iter 80: Loss=0.00240
#     Grad a=-0.0003 -> Update a to -0.007
#     Grad b=0.0003 -> Update b to -1.572
#     Grad c=-0.0003 -> Update c to 3.208
#     Grad d=-0.0004 -> Update d to -1.295
# Iter 81: Loss=0.00240
#     Grad a=-0.0003 -> Update a to -0.007
#     Grad b=0.0003 -> Update b to -1.572
#     Grad c=-0.0003 -> Update c to 3.209
#     Grad d=-0.0004 -> Update d to -1.295
# Iter 82: Loss=0.00240
#     Grad a=-0.0003 -> Update a to -0.006
#     Grad b=0.0003 -> Update b to -1.572
#     Grad c=-0.0003 -> Update c to 3.210
#     Grad d=-0.0004 -> Update d to -1.294
# Iter 83: Loss=0.00240
#     Grad a=-0.0003 -> Update a to -0.006
#     Grad b=0.0003 -> Update b to -1.573
#     Grad c=-0.0003 -> Update c to 3.211
#     Grad d=-0.0004 -> Update d to -1.294
# Iter 84: Loss=0.00240
#     Grad a=-0.0003 -> Update a to -0.006
#     Grad b=0.0003 -> Update b to -1.573
#     Grad c=-0.0003 -> Update c to 3.211
#     Grad d=-0.0004 -> Update d to -1.293
# Iter 85: Loss=0.00240
#     Grad a=-0.0003 -> Update a to -0.005
#     Grad b=0.0003 -> Update b to -1.573
#     Grad c=-0.0003 -> Update c to 3.212
#     Grad d=-0.0004 -> Update d to -1.293
# Iter 86: Loss=0.00239
#     Grad a=-0.0003 -> Update a to -0.005
#     Grad b=0.0003 -> Update b to -1.574
#     Grad c=-0.0003 -> Update c to 3.213
#     Grad d=-0.0004 -> Update d to -1.293
# Iter 87: Loss=0.00239
#     Grad a=-0.0003 -> Update a to -0.005
#     Grad b=0.0003 -> Update b to -1.574
#     Grad c=-0.0003 -> Update c to 3.214
#     Grad d=-0.0004 -> Update d to -1.292
# Iter 88: Loss=0.00239
#     Grad a=-0.0003 -> Update a to -0.005
#     Grad b=0.0003 -> Update b to -1.574
#     Grad c=-0.0003 -> Update c to 3.215
#     Grad d=-0.0004 -> Update d to -1.292
# Iter 89: Loss=0.00239
#     Grad a=-0.0003 -> Update a to -0.004
#     Grad b=0.0003 -> Update b to -1.575
#     Grad c=-0.0003 -> Update c to 3.215
#     Grad d=-0.0004 -> Update d to -1.292
# Iter 90: Loss=0.00239
#     Grad a=-0.0003 -> Update a to -0.004
#     Grad b=0.0003 -> Update b to -1.575
#     Grad c=-0.0002 -> Update c to 3.216
#     Grad d=-0.0004 -> Update d to -1.291
# Iter 91: Loss=0.00239
#     Grad a=-0.0003 -> Update a to -0.004
#     Grad b=0.0003 -> Update b to -1.575
#     Grad c=-0.0002 -> Update c to 3.217
#     Grad d=-0.0003 -> Update d to -1.291
# Iter 92: Loss=0.00239
#     Grad a=-0.0003 -> Update a to -0.003
#     Grad b=0.0003 -> Update b to -1.576
#     Grad c=-0.0002 -> Update c to 3.218
#     Grad d=-0.0003 -> Update d to -1.290
# Iter 93: Loss=0.00239
#     Grad a=-0.0003 -> Update a to -0.003
#     Grad b=0.0003 -> Update b to -1.576
#     Grad c=-0.0002 -> Update c to 3.218
#     Grad d=-0.0003 -> Update d to -1.290
# Iter 94: Loss=0.00239
#     Grad a=-0.0003 -> Update a to -0.003
#     Grad b=0.0003 -> Update b to -1.576
#     Grad c=-0.0002 -> Update c to 3.219
#     Grad d=-0.0003 -> Update d to -1.290
# Iter 95: Loss=0.00239
#     Grad a=-0.0003 -> Update a to -0.003
#     Grad b=0.0003 -> Update b to -1.577
#     Grad c=-0.0002 -> Update c to 3.220
#     Grad d=-0.0003 -> Update d to -1.290
# Iter 96: Loss=0.00239
#     Grad a=-0.0003 -> Update a to -0.002
#     Grad b=0.0003 -> Update b to -1.577
#     Grad c=-0.0002 -> Update c to 3.220
#     Grad d=-0.0003 -> Update d to -1.289
# Iter 97: Loss=0.00239
#     Grad a=-0.0003 -> Update a to -0.002
#     Grad b=0.0003 -> Update b to -1.577
#     Grad c=-0.0002 -> Update c to 3.221
#     Grad d=-0.0003 -> Update d to -1.289
# Iter 98: Loss=0.00239
#     Grad a=-0.0003 -> Update a to -0.002
#     Grad b=0.0003 -> Update b to -1.578
#     Grad c=-0.0002 -> Update c to 3.222
#     Grad d=-0.0003 -> Update d to -1.289
# Iter 99: Loss=0.00239
#     Grad a=-0.0003 -> Update a to -0.001
#     Grad b=0.0003 -> Update b to -1.578
#     Grad c=-0.0002 -> Update c to 3.222
#     Grad d=-0.0003 -> Update d to -1.288
# Iter 100: Loss=0.00239
#     Grad a=-0.0003 -> Update a to -0.001
#     Grad b=0.0003 -> Update b to -1.578
#     Grad c=-0.0002 -> Update c to 3.223
#     Grad d=-0.0003 -> Update d to -1.288
# Iter 101: Loss=0.00239
#     Grad a=-0.0003 -> Update a to -0.001
#     Grad b=0.0003 -> Update b to -1.579
#     Grad c=-0.0002 -> Update c to 3.223
#     Grad d=-0.0003 -> Update d to -1.288
# Iter 102: Loss=0.00239
#     Grad a=-0.0003 -> Update a to -0.001
#     Grad b=0.0003 -> Update b to -1.579
#     Grad c=-0.0002 -> Update c to 3.224
#     Grad d=-0.0003 -> Update d to -1.287
# Iter 103: Loss=0.00239
#     Grad a=-0.0003 -> Update a to -0.000
#     Grad b=0.0003 -> Update b to -1.579
#     Grad c=-0.0002 -> Update c to 3.225
#     Grad d=-0.0003 -> Update d to -1.287
# Iter 104: Loss=0.00239
#     Grad a=-0.0003 -> Update a to -0.000
#     Grad b=0.0003 -> Update b to -1.580
#     Grad c=-0.0002 -> Update c to 3.225
#     Grad d=-0.0003 -> Update d to -1.287
# Iter 105: Loss=0.00239
#     Grad a=-0.0003 -> Update a to 0.000
#     Grad b=0.0003 -> Update b to -1.580
#     Grad c=-0.0002 -> Update c to 3.226
#     Grad d=-0.0003 -> Update d to -1.287
# Iter 106: Loss=0.00239
#     Grad a=-0.0003 -> Update a to 0.000
#     Grad b=0.0003 -> Update b to -1.580
#     Grad c=-0.0002 -> Update c to 3.226
#     Grad d=-0.0003 -> Update d to -1.286
# Iter 107: Loss=0.00239
#     Grad a=-0.0003 -> Update a to 0.001
#     Grad b=0.0003 -> Update b to -1.581
#     Grad c=-0.0002 -> Update c to 3.227
#     Grad d=-0.0003 -> Update d to -1.286
# Iter 108: Loss=0.00238
#     Grad a=-0.0003 -> Update a to 0.001
#     Grad b=0.0003 -> Update b to -1.581
#     Grad c=-0.0002 -> Update c to 3.227
#     Grad d=-0.0002 -> Update d to -1.286
# Iter 109: Loss=0.00238
#     Grad a=-0.0003 -> Update a to 0.001
#     Grad b=0.0003 -> Update b to -1.581
#     Grad c=-0.0002 -> Update c to 3.228
#     Grad d=-0.0002 -> Update d to -1.286
# Iter 110: Loss=0.00238
#     Grad a=-0.0003 -> Update a to 0.002
#     Grad b=0.0003 -> Update b to -1.582
#     Grad c=-0.0002 -> Update c to 3.228
#     Grad d=-0.0002 -> Update d to -1.285
# Iter 111: Loss=0.00238
#     Grad a=-0.0003 -> Update a to 0.002
#     Grad b=0.0003 -> Update b to -1.582
#     Grad c=-0.0002 -> Update c to 3.229
#     Grad d=-0.0002 -> Update d to -1.285
# Iter 112: Loss=0.00238
#     Grad a=-0.0003 -> Update a to 0.002
#     Grad b=0.0003 -> Update b to -1.582
#     Grad c=-0.0002 -> Update c to 3.230
#     Grad d=-0.0002 -> Update d to -1.285
# Iter 113: Loss=0.00238
#     Grad a=-0.0003 -> Update a to 0.002
#     Grad b=0.0003 -> Update b to -1.582
#     Grad c=-0.0002 -> Update c to 3.230
#     Grad d=-0.0002 -> Update d to -1.285
# Iter 114: Loss=0.00238
#     Grad a=-0.0003 -> Update a to 0.003
#     Grad b=0.0003 -> Update b to -1.583
#     Grad c=-0.0002 -> Update c to 3.231
#     Grad d=-0.0002 -> Update d to -1.285
# Iter 115: Loss=0.00238
#     Grad a=-0.0003 -> Update a to 0.003
#     Grad b=0.0003 -> Update b to -1.583
#     Grad c=-0.0002 -> Update c to 3.231
#     Grad d=-0.0002 -> Update d to -1.284
# Iter 116: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.003
#     Grad b=0.0003 -> Update b to -1.583
#     Grad c=-0.0002 -> Update c to 3.232
#     Grad d=-0.0002 -> Update d to -1.284
# Iter 117: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.003
#     Grad b=0.0003 -> Update b to -1.584
#     Grad c=-0.0002 -> Update c to 3.232
#     Grad d=-0.0002 -> Update d to -1.284
# Iter 118: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.004
#     Grad b=0.0003 -> Update b to -1.584
#     Grad c=-0.0002 -> Update c to 3.232
#     Grad d=-0.0002 -> Update d to -1.284
# Iter 119: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.004
#     Grad b=0.0003 -> Update b to -1.584
#     Grad c=-0.0002 -> Update c to 3.233
#     Grad d=-0.0002 -> Update d to -1.283
# Iter 120: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.004
#     Grad b=0.0003 -> Update b to -1.585
#     Grad c=-0.0002 -> Update c to 3.233
#     Grad d=-0.0002 -> Update d to -1.283
# Iter 121: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.004
#     Grad b=0.0003 -> Update b to -1.585
#     Grad c=-0.0002 -> Update c to 3.234
#     Grad d=-0.0002 -> Update d to -1.283
# Iter 122: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.004
#     Grad b=0.0003 -> Update b to -1.585
#     Grad c=-0.0002 -> Update c to 3.234
#     Grad d=-0.0002 -> Update d to -1.283
# Iter 123: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.005
#     Grad b=0.0003 -> Update b to -1.585
#     Grad c=-0.0001 -> Update c to 3.235
#     Grad d=-0.0002 -> Update d to -1.283
# Iter 124: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.005
#     Grad b=0.0003 -> Update b to -1.586
#     Grad c=-0.0001 -> Update c to 3.235
#     Grad d=-0.0002 -> Update d to -1.282
# Iter 125: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.005
#     Grad b=0.0003 -> Update b to -1.586
#     Grad c=-0.0001 -> Update c to 3.236
#     Grad d=-0.0002 -> Update d to -1.282
# Iter 126: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.005
#     Grad b=0.0003 -> Update b to -1.586
#     Grad c=-0.0001 -> Update c to 3.236
#     Grad d=-0.0002 -> Update d to -1.282
# Iter 127: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.006
#     Grad b=0.0003 -> Update b to -1.587
#     Grad c=-0.0001 -> Update c to 3.237
#     Grad d=-0.0002 -> Update d to -1.282
# Iter 128: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.006
#     Grad b=0.0003 -> Update b to -1.587
#     Grad c=-0.0001 -> Update c to 3.237
#     Grad d=-0.0002 -> Update d to -1.282
# Iter 129: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.006
#     Grad b=0.0003 -> Update b to -1.587
#     Grad c=-0.0001 -> Update c to 3.237
#     Grad d=-0.0002 -> Update d to -1.281
# Iter 130: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.006
#     Grad b=0.0003 -> Update b to -1.587
#     Grad c=-0.0001 -> Update c to 3.238
#     Grad d=-0.0002 -> Update d to -1.281
# Iter 131: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.007
#     Grad b=0.0003 -> Update b to -1.588
#     Grad c=-0.0001 -> Update c to 3.238
#     Grad d=-0.0002 -> Update d to -1.281
# Iter 132: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.007
#     Grad b=0.0003 -> Update b to -1.588
#     Grad c=-0.0001 -> Update c to 3.239
#     Grad d=-0.0002 -> Update d to -1.281
# Iter 133: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.007
#     Grad b=0.0003 -> Update b to -1.588
#     Grad c=-0.0001 -> Update c to 3.239
#     Grad d=-0.0002 -> Update d to -1.281
# Iter 134: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.007
#     Grad b=0.0003 -> Update b to -1.589
#     Grad c=-0.0001 -> Update c to 3.239
#     Grad d=-0.0002 -> Update d to -1.281
# Iter 135: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.007
#     Grad b=0.0003 -> Update b to -1.589
#     Grad c=-0.0001 -> Update c to 3.240
#     Grad d=-0.0002 -> Update d to -1.280
# Iter 136: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.008
#     Grad b=0.0003 -> Update b to -1.589
#     Grad c=-0.0001 -> Update c to 3.240
#     Grad d=-0.0002 -> Update d to -1.280
# Iter 137: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.008
#     Grad b=0.0003 -> Update b to -1.589
#     Grad c=-0.0001 -> Update c to 3.241
#     Grad d=-0.0002 -> Update d to -1.280
# Iter 138: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.008
#     Grad b=0.0003 -> Update b to -1.590
#     Grad c=-0.0001 -> Update c to 3.241
#     Grad d=-0.0002 -> Update d to -1.280
# Iter 139: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.008
#     Grad b=0.0003 -> Update b to -1.590
#     Grad c=-0.0001 -> Update c to 3.241
#     Grad d=-0.0002 -> Update d to -1.280
# Iter 140: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.008
#     Grad b=0.0003 -> Update b to -1.590
#     Grad c=-0.0001 -> Update c to 3.242
#     Grad d=-0.0002 -> Update d to -1.280
# Iter 141: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.009
#     Grad b=0.0003 -> Update b to -1.590
#     Grad c=-0.0001 -> Update c to 3.242
#     Grad d=-0.0002 -> Update d to -1.279
# Iter 142: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.009
#     Grad b=0.0003 -> Update b to -1.591
#     Grad c=-0.0001 -> Update c to 3.242
#     Grad d=-0.0002 -> Update d to -1.279
# Iter 143: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.009
#     Grad b=0.0003 -> Update b to -1.591
#     Grad c=-0.0001 -> Update c to 3.243
#     Grad d=-0.0002 -> Update d to -1.279
# Iter 144: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.009
#     Grad b=0.0003 -> Update b to -1.591
#     Grad c=-0.0001 -> Update c to 3.243
#     Grad d=-0.0002 -> Update d to -1.279
# Iter 145: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.009
#     Grad b=0.0002 -> Update b to -1.591
#     Grad c=-0.0001 -> Update c to 3.243
#     Grad d=-0.0002 -> Update d to -1.279
# Iter 146: Loss=0.00238
#     Grad a=-0.0002 -> Update a to 0.010
#     Grad b=0.0002 -> Update b to -1.592
#     Grad c=-0.0001 -> Update c to 3.244
#     Grad d=-0.0002 -> Update d to -1.279
# Iter 147: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.010
#     Grad b=0.0002 -> Update b to -1.592
#     Grad c=-0.0001 -> Update c to 3.244
#     Grad d=-0.0002 -> Update d to -1.278
# Iter 148: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.010
#     Grad b=0.0002 -> Update b to -1.592
#     Grad c=-0.0001 -> Update c to 3.245
#     Grad d=-0.0001 -> Update d to -1.278
# Iter 149: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.010
#     Grad b=0.0002 -> Update b to -1.592
#     Grad c=-0.0001 -> Update c to 3.245
#     Grad d=-0.0001 -> Update d to -1.278
# Iter 150: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.010
#     Grad b=0.0002 -> Update b to -1.593
#     Grad c=-0.0001 -> Update c to 3.245
#     Grad d=-0.0001 -> Update d to -1.278
# Iter 151: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.011
#     Grad b=0.0002 -> Update b to -1.593
#     Grad c=-0.0001 -> Update c to 3.246
#     Grad d=-0.0001 -> Update d to -1.278
# Iter 152: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.011
#     Grad b=0.0002 -> Update b to -1.593
#     Grad c=-0.0001 -> Update c to 3.246
#     Grad d=-0.0001 -> Update d to -1.278
# Iter 153: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.011
#     Grad b=0.0002 -> Update b to -1.593
#     Grad c=-0.0001 -> Update c to 3.246
#     Grad d=-0.0001 -> Update d to -1.278
# Iter 154: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.011
#     Grad b=0.0002 -> Update b to -1.594
#     Grad c=-0.0001 -> Update c to 3.246
#     Grad d=-0.0001 -> Update d to -1.277
# Iter 155: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.011
#     Grad b=0.0002 -> Update b to -1.594
#     Grad c=-0.0001 -> Update c to 3.247
#     Grad d=-0.0001 -> Update d to -1.277
# Iter 156: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.012
#     Grad b=0.0002 -> Update b to -1.594
#     Grad c=-0.0001 -> Update c to 3.247
#     Grad d=-0.0001 -> Update d to -1.277
# Iter 157: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.012
#     Grad b=0.0002 -> Update b to -1.594
#     Grad c=-0.0001 -> Update c to 3.247
#     Grad d=-0.0001 -> Update d to -1.277
# Iter 158: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.012
#     Grad b=0.0002 -> Update b to -1.594
#     Grad c=-0.0001 -> Update c to 3.248
#     Grad d=-0.0001 -> Update d to -1.277
# Iter 159: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.012
#     Grad b=0.0002 -> Update b to -1.595
#     Grad c=-0.0001 -> Update c to 3.248
#     Grad d=-0.0001 -> Update d to -1.277
# Iter 160: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.012
#     Grad b=0.0002 -> Update b to -1.595
#     Grad c=-0.0001 -> Update c to 3.248
#     Grad d=-0.0001 -> Update d to -1.277
# Iter 161: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.012
#     Grad b=0.0002 -> Update b to -1.595
#     Grad c=-0.0001 -> Update c to 3.249
#     Grad d=-0.0001 -> Update d to -1.277
# Iter 162: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.013
#     Grad b=0.0002 -> Update b to -1.595
#     Grad c=-0.0001 -> Update c to 3.249
#     Grad d=-0.0001 -> Update d to -1.276
# Iter 163: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.013
#     Grad b=0.0002 -> Update b to -1.596
#     Grad c=-0.0001 -> Update c to 3.249
#     Grad d=-0.0001 -> Update d to -1.276
# Iter 164: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.013
#     Grad b=0.0002 -> Update b to -1.596
#     Grad c=-0.0001 -> Update c to 3.250
#     Grad d=-0.0001 -> Update d to -1.276
# Iter 165: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.013
#     Grad b=0.0002 -> Update b to -1.596
#     Grad c=-0.0001 -> Update c to 3.250
#     Grad d=-0.0001 -> Update d to -1.276
# Iter 166: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.013
#     Grad b=0.0002 -> Update b to -1.596
#     Grad c=-0.0001 -> Update c to 3.250
#     Grad d=-0.0001 -> Update d to -1.276
# Iter 167: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.013
#     Grad b=0.0002 -> Update b to -1.596
#     Grad c=-0.0001 -> Update c to 3.250
#     Grad d=-0.0001 -> Update d to -1.276
# Iter 168: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.014
#     Grad b=0.0002 -> Update b to -1.597
#     Grad c=-0.0001 -> Update c to 3.251
#     Grad d=-0.0001 -> Update d to -1.276
# Iter 169: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.014
#     Grad b=0.0002 -> Update b to -1.597
#     Grad c=-0.0001 -> Update c to 3.251
#     Grad d=-0.0001 -> Update d to -1.276
# Iter 170: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.014
#     Grad b=0.0002 -> Update b to -1.597
#     Grad c=-0.0001 -> Update c to 3.251
#     Grad d=-0.0001 -> Update d to -1.275
# Iter 171: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.014
#     Grad b=0.0002 -> Update b to -1.597
#     Grad c=-0.0001 -> Update c to 3.252
#     Grad d=-0.0001 -> Update d to -1.275
# Iter 172: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.014
#     Grad b=0.0002 -> Update b to -1.597
#     Grad c=-0.0001 -> Update c to 3.252
#     Grad d=-0.0001 -> Update d to -1.275
# Iter 173: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.014
#     Grad b=0.0002 -> Update b to -1.598
#     Grad c=-0.0001 -> Update c to 3.252
#     Grad d=-0.0001 -> Update d to -1.275
# Iter 174: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.015
#     Grad b=0.0002 -> Update b to -1.598
#     Grad c=-0.0001 -> Update c to 3.252
#     Grad d=-0.0001 -> Update d to -1.275
# Iter 175: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.015
#     Grad b=0.0002 -> Update b to -1.598
#     Grad c=-0.0001 -> Update c to 3.253
#     Grad d=-0.0001 -> Update d to -1.275
# Iter 176: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.015
#     Grad b=0.0002 -> Update b to -1.598
#     Grad c=-0.0001 -> Update c to 3.253
#     Grad d=-0.0001 -> Update d to -1.275
# Iter 177: Loss=0.00237
#     Grad a=-0.0002 -> Update a to 0.015
#     Grad b=0.0002 -> Update b to -1.598
#     Grad c=-0.0001 -> Update c to 3.253
#     Grad d=-0.0001 -> Update d to -1.275
# Iter 178: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.015
#     Grad b=0.0002 -> Update b to -1.599
#     Grad c=-0.0001 -> Update c to 3.253
#     Grad d=-0.0001 -> Update d to -1.274
# Iter 179: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.015
#     Grad b=0.0002 -> Update b to -1.599
#     Grad c=-0.0001 -> Update c to 3.254
#     Grad d=-0.0001 -> Update d to -1.274
# Iter 180: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.015
#     Grad b=0.0002 -> Update b to -1.599
#     Grad c=-0.0001 -> Update c to 3.254
#     Grad d=-0.0001 -> Update d to -1.274
# Iter 181: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.016
#     Grad b=0.0002 -> Update b to -1.599
#     Grad c=-0.0001 -> Update c to 3.254
#     Grad d=-0.0001 -> Update d to -1.274
# Iter 182: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.016
#     Grad b=0.0002 -> Update b to -1.599
#     Grad c=-0.0001 -> Update c to 3.254
#     Grad d=-0.0001 -> Update d to -1.274
# Iter 183: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.016
#     Grad b=0.0002 -> Update b to -1.599
#     Grad c=-0.0001 -> Update c to 3.255
#     Grad d=-0.0001 -> Update d to -1.274
# Iter 184: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.016
#     Grad b=0.0002 -> Update b to -1.600
#     Grad c=-0.0001 -> Update c to 3.255
#     Grad d=-0.0001 -> Update d to -1.274
# Iter 185: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.016
#     Grad b=0.0002 -> Update b to -1.600
#     Grad c=-0.0001 -> Update c to 3.255
#     Grad d=-0.0001 -> Update d to -1.274
# Iter 186: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.016
#     Grad b=0.0002 -> Update b to -1.600
#     Grad c=-0.0001 -> Update c to 3.255
#     Grad d=-0.0001 -> Update d to -1.274
# Iter 187: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.016
#     Grad b=0.0002 -> Update b to -1.600
#     Grad c=-0.0001 -> Update c to 3.256
#     Grad d=-0.0001 -> Update d to -1.274
# Iter 188: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.017
#     Grad b=0.0002 -> Update b to -1.600
#     Grad c=-0.0001 -> Update c to 3.256
#     Grad d=-0.0001 -> Update d to -1.273
# Iter 189: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.017
#     Grad b=0.0002 -> Update b to -1.601
#     Grad c=-0.0001 -> Update c to 3.256
#     Grad d=-0.0001 -> Update d to -1.273
# Iter 190: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.017
#     Grad b=0.0002 -> Update b to -1.601
#     Grad c=-0.0001 -> Update c to 3.256
#     Grad d=-0.0001 -> Update d to -1.273
# Iter 191: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.017
#     Grad b=0.0002 -> Update b to -1.601
#     Grad c=-0.0001 -> Update c to 3.257
#     Grad d=-0.0001 -> Update d to -1.273
# Iter 192: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.017
#     Grad b=0.0002 -> Update b to -1.601
#     Grad c=-0.0001 -> Update c to 3.257
#     Grad d=-0.0001 -> Update d to -1.273
# Iter 193: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.017
#     Grad b=0.0002 -> Update b to -1.601
#     Grad c=-0.0001 -> Update c to 3.257
#     Grad d=-0.0001 -> Update d to -1.273
# Iter 194: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.017
#     Grad b=0.0002 -> Update b to -1.601
#     Grad c=-0.0001 -> Update c to 3.257
#     Grad d=-0.0001 -> Update d to -1.273
# Iter 195: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.018
#     Grad b=0.0002 -> Update b to -1.602
#     Grad c=-0.0001 -> Update c to 3.257
#     Grad d=-0.0001 -> Update d to -1.273
# Iter 196: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.018
#     Grad b=0.0002 -> Update b to -1.602
#     Grad c=-0.0001 -> Update c to 3.258
#     Grad d=-0.0001 -> Update d to -1.273
# Iter 197: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.018
#     Grad b=0.0002 -> Update b to -1.602
#     Grad c=-0.0001 -> Update c to 3.258
#     Grad d=-0.0001 -> Update d to -1.273
# Iter 198: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.018
#     Grad b=0.0002 -> Update b to -1.602
#     Grad c=-0.0001 -> Update c to 3.258
#     Grad d=-0.0001 -> Update d to -1.272
# Iter 199: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.018
#     Grad b=0.0002 -> Update b to -1.602
#     Grad c=-0.0001 -> Update c to 3.258
#     Grad d=-0.0001 -> Update d to -1.272
# Iter 200: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.018
#     Grad b=0.0002 -> Update b to -1.602
#     Grad c=-0.0001 -> Update c to 3.259
#     Grad d=-0.0001 -> Update d to -1.272
# Iter 201: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.018
#     Grad b=0.0002 -> Update b to -1.602
#     Grad c=-0.0001 -> Update c to 3.259
#     Grad d=-0.0001 -> Update d to -1.272
# Iter 202: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.018
#     Grad b=0.0002 -> Update b to -1.603
#     Grad c=-0.0001 -> Update c to 3.259
#     Grad d=-0.0001 -> Update d to -1.272
# Iter 203: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.018
#     Grad b=0.0002 -> Update b to -1.603
#     Grad c=-0.0001 -> Update c to 3.259
#     Grad d=-0.0001 -> Update d to -1.272
# Iter 204: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.019
#     Grad b=0.0002 -> Update b to -1.603
#     Grad c=-0.0001 -> Update c to 3.259
#     Grad d=-0.0001 -> Update d to -1.272
# Iter 205: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.019
#     Grad b=0.0001 -> Update b to -1.603
#     Grad c=-0.0001 -> Update c to 3.260
#     Grad d=-0.0001 -> Update d to -1.272
# Iter 206: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.019
#     Grad b=0.0001 -> Update b to -1.603
#     Grad c=-0.0001 -> Update c to 3.260
#     Grad d=-0.0001 -> Update d to -1.272
# Iter 207: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.019
#     Grad b=0.0001 -> Update b to -1.603
#     Grad c=-0.0001 -> Update c to 3.260
#     Grad d=-0.0001 -> Update d to -1.272
# Iter 208: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.019
#     Grad b=0.0001 -> Update b to -1.604
#     Grad c=-0.0001 -> Update c to 3.260
#     Grad d=-0.0001 -> Update d to -1.272
# Iter 209: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.019
#     Grad b=0.0001 -> Update b to -1.604
#     Grad c=-0.0001 -> Update c to 3.260
#     Grad d=-0.0001 -> Update d to -1.271
# Iter 210: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.019
#     Grad b=0.0001 -> Update b to -1.604
#     Grad c=-0.0001 -> Update c to 3.261
#     Grad d=-0.0001 -> Update d to -1.271
# Iter 211: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.019
#     Grad b=0.0001 -> Update b to -1.604
#     Grad c=-0.0001 -> Update c to 3.261
#     Grad d=-0.0001 -> Update d to -1.271
# Iter 212: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.020
#     Grad b=0.0001 -> Update b to -1.604
#     Grad c=-0.0001 -> Update c to 3.261
#     Grad d=-0.0001 -> Update d to -1.271
# Iter 213: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.020
#     Grad b=0.0001 -> Update b to -1.604
#     Grad c=-0.0001 -> Update c to 3.261
#     Grad d=-0.0001 -> Update d to -1.271
# Iter 214: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.020
#     Grad b=0.0001 -> Update b to -1.604
#     Grad c=-0.0001 -> Update c to 3.261
#     Grad d=-0.0001 -> Update d to -1.271
# Iter 215: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.020
#     Grad b=0.0001 -> Update b to -1.604
#     Grad c=-0.0001 -> Update c to 3.262
#     Grad d=-0.0001 -> Update d to -1.271
# Iter 216: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.020
#     Grad b=0.0001 -> Update b to -1.605
#     Grad c=-0.0001 -> Update c to 3.262
#     Grad d=-0.0001 -> Update d to -1.271
# Iter 217: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.020
#     Grad b=0.0001 -> Update b to -1.605
#     Grad c=-0.0001 -> Update c to 3.262
#     Grad d=-0.0001 -> Update d to -1.271
# Iter 218: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.020
#     Grad b=0.0001 -> Update b to -1.605
#     Grad c=-0.0001 -> Update c to 3.262
#     Grad d=-0.0001 -> Update d to -1.271
# Iter 219: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.020
#     Grad b=0.0001 -> Update b to -1.605
#     Grad c=-0.0001 -> Update c to 3.262
#     Grad d=-0.0001 -> Update d to -1.271
# Iter 220: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.020
#     Grad b=0.0001 -> Update b to -1.605
#     Grad c=-0.0001 -> Update c to 3.263
#     Grad d=-0.0001 -> Update d to -1.271
# Iter 221: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.020
#     Grad b=0.0001 -> Update b to -1.605
#     Grad c=-0.0001 -> Update c to 3.263
#     Grad d=-0.0001 -> Update d to -1.270
# Iter 222: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.021
#     Grad b=0.0001 -> Update b to -1.605
#     Grad c=-0.0001 -> Update c to 3.263
#     Grad d=-0.0001 -> Update d to -1.270
# Iter 223: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.021
#     Grad b=0.0001 -> Update b to -1.606
#     Grad c=-0.0001 -> Update c to 3.263
#     Grad d=-0.0001 -> Update d to -1.270
# Iter 224: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.021
#     Grad b=0.0001 -> Update b to -1.606
#     Grad c=-0.0001 -> Update c to 3.263
#     Grad d=-0.0001 -> Update d to -1.270
# Iter 225: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.021
#     Grad b=0.0001 -> Update b to -1.606
#     Grad c=-0.0001 -> Update c to 3.263
#     Grad d=-0.0001 -> Update d to -1.270
# Iter 226: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.021
#     Grad b=0.0001 -> Update b to -1.606
#     Grad c=-0.0001 -> Update c to 3.264
#     Grad d=-0.0001 -> Update d to -1.270
# Iter 227: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.021
#     Grad b=0.0001 -> Update b to -1.606
#     Grad c=-0.0001 -> Update c to 3.264
#     Grad d=-0.0001 -> Update d to -1.270
# Iter 228: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.021
#     Grad b=0.0001 -> Update b to -1.606
#     Grad c=-0.0001 -> Update c to 3.264
#     Grad d=-0.0001 -> Update d to -1.270
# Iter 229: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.021
#     Grad b=0.0001 -> Update b to -1.606
#     Grad c=-0.0001 -> Update c to 3.264
#     Grad d=-0.0001 -> Update d to -1.270
# Iter 230: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.021
#     Grad b=0.0001 -> Update b to -1.606
#     Grad c=-0.0001 -> Update c to 3.264
#     Grad d=-0.0001 -> Update d to -1.270
# Iter 231: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.021
#     Grad b=0.0001 -> Update b to -1.607
#     Grad c=-0.0001 -> Update c to 3.264
#     Grad d=-0.0001 -> Update d to -1.270
# Iter 232: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.022
#     Grad b=0.0001 -> Update b to -1.607
#     Grad c=-0.0001 -> Update c to 3.265
#     Grad d=-0.0001 -> Update d to -1.270
# Iter 233: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.022
#     Grad b=0.0001 -> Update b to -1.607
#     Grad c=-0.0001 -> Update c to 3.265
#     Grad d=-0.0001 -> Update d to -1.270
# Iter 234: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.022
#     Grad b=0.0001 -> Update b to -1.607
#     Grad c=-0.0001 -> Update c to 3.265
#     Grad d=-0.0001 -> Update d to -1.270
# Iter 235: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.022
#     Grad b=0.0001 -> Update b to -1.607
#     Grad c=-0.0001 -> Update c to 3.265
#     Grad d=-0.0001 -> Update d to -1.269
# Iter 236: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.022
#     Grad b=0.0001 -> Update b to -1.607
#     Grad c=-0.0001 -> Update c to 3.265
#     Grad d=-0.0001 -> Update d to -1.269
# Iter 237: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.022
#     Grad b=0.0001 -> Update b to -1.607
#     Grad c=-0.0001 -> Update c to 3.265
#     Grad d=-0.0001 -> Update d to -1.269
# Iter 238: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.022
#     Grad b=0.0001 -> Update b to -1.607
#     Grad c=-0.0001 -> Update c to 3.266
#     Grad d=-0.0001 -> Update d to -1.269
# Iter 239: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.022
#     Grad b=0.0001 -> Update b to -1.607
#     Grad c=-0.0001 -> Update c to 3.266
#     Grad d=-0.0001 -> Update d to -1.269
# Iter 240: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.022
#     Grad b=0.0001 -> Update b to -1.608
#     Grad c=-0.0001 -> Update c to 3.266
#     Grad d=-0.0001 -> Update d to -1.269
# Iter 241: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.022
#     Grad b=0.0001 -> Update b to -1.608
#     Grad c=-0.0001 -> Update c to 3.266
#     Grad d=-0.0001 -> Update d to -1.269
# Iter 242: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.022
#     Grad b=0.0001 -> Update b to -1.608
#     Grad c=-0.0001 -> Update c to 3.266
#     Grad d=-0.0001 -> Update d to -1.269
# Iter 243: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.023
#     Grad b=0.0001 -> Update b to -1.608
#     Grad c=-0.0001 -> Update c to 3.266
#     Grad d=-0.0001 -> Update d to -1.269
# Iter 244: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.023
#     Grad b=0.0001 -> Update b to -1.608
#     Grad c=-0.0000 -> Update c to 3.266
#     Grad d=-0.0001 -> Update d to -1.269
# Iter 245: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.023
#     Grad b=0.0001 -> Update b to -1.608
#     Grad c=-0.0000 -> Update c to 3.267
#     Grad d=-0.0001 -> Update d to -1.269
# Iter 246: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.023
#     Grad b=0.0001 -> Update b to -1.608
#     Grad c=-0.0000 -> Update c to 3.267
#     Grad d=-0.0001 -> Update d to -1.269
# Iter 247: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.023
#     Grad b=0.0001 -> Update b to -1.608
#     Grad c=-0.0000 -> Update c to 3.267
#     Grad d=-0.0001 -> Update d to -1.269
# Iter 248: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.023
#     Grad b=0.0001 -> Update b to -1.608
#     Grad c=-0.0000 -> Update c to 3.267
#     Grad d=-0.0001 -> Update d to -1.269
# Iter 249: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.023
#     Grad b=0.0001 -> Update b to -1.609
#     Grad c=-0.0000 -> Update c to 3.267
#     Grad d=-0.0001 -> Update d to -1.269
# Iter 250: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.023
#     Grad b=0.0001 -> Update b to -1.609
#     Grad c=-0.0000 -> Update c to 3.267
#     Grad d=-0.0001 -> Update d to -1.268
# Iter 251: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.023
#     Grad b=0.0001 -> Update b to -1.609
#     Grad c=-0.0000 -> Update c to 3.267
#     Grad d=-0.0001 -> Update d to -1.268
# Iter 252: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.023
#     Grad b=0.0001 -> Update b to -1.609
#     Grad c=-0.0000 -> Update c to 3.268
#     Grad d=-0.0001 -> Update d to -1.268
# Iter 253: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.023
#     Grad b=0.0001 -> Update b to -1.609
#     Grad c=-0.0000 -> Update c to 3.268
#     Grad d=-0.0001 -> Update d to -1.268
# Iter 254: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.023
#     Grad b=0.0001 -> Update b to -1.609
#     Grad c=-0.0000 -> Update c to 3.268
#     Grad d=-0.0001 -> Update d to -1.268
# Iter 255: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.024
#     Grad b=0.0001 -> Update b to -1.609
#     Grad c=-0.0000 -> Update c to 3.268
#     Grad d=-0.0001 -> Update d to -1.268
# Iter 256: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.024
#     Grad b=0.0001 -> Update b to -1.609
#     Grad c=-0.0000 -> Update c to 3.268
#     Grad d=-0.0001 -> Update d to -1.268
# Iter 257: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.024
#     Grad b=0.0001 -> Update b to -1.609
#     Grad c=-0.0000 -> Update c to 3.268
#     Grad d=-0.0001 -> Update d to -1.268
# Iter 258: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.024
#     Grad b=0.0001 -> Update b to -1.609
#     Grad c=-0.0000 -> Update c to 3.268
#     Grad d=-0.0001 -> Update d to -1.268
# Iter 259: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.024
#     Grad b=0.0001 -> Update b to -1.610
#     Grad c=-0.0000 -> Update c to 3.269
#     Grad d=-0.0001 -> Update d to -1.268
# Iter 260: Loss=0.00237
#     Grad a=-0.0001 -> Update a to 0.024
# ...
# Iter 414: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.030
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.280
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 415: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.030
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.280
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 416: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.030
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.280
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 417: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.030
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.280
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 418: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.030
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.280
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 419: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.030
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.280
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 420: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.030
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.280
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 421: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.030
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.280
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 422: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.030
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.280
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 423: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.030
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.280
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 424: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.030
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.280
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 425: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.030
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.280
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 426: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.030
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.280
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 427: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.030
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 428: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 429: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 430: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 431: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 432: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 433: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 434: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 435: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 436: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 437: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 438: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 439: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 440: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 441: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 442: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 443: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 444: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 445: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 446: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 447: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.618
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 448: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 449: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 450: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 451: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 452: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 453: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 454: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 455: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 456: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.263
# Iter 457: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 458: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 459: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 460: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.281
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 461: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 462: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 463: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 464: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 465: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 466: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 467: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 468: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 469: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 470: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 471: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 472: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 473: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 474: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 475: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 476: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 477: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 478: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 479: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 480: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 481: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 482: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 483: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 484: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 485: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 486: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 487: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 488: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 489: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 490: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 491: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 492: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 493: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 494: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 495: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 496: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 497: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 498: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Iter 499: Loss=0.00237
#     Grad a=-0.0000 -> Update a to 0.031
#     Grad b=0.0000 -> Update b to -1.619
#     Grad c=-0.0000 -> Update c to 3.282
#     Grad d=-0.0000 -> Update d to -1.262
# Final Estimated a: 0.031 (True: 0)
# Final Estimated b: -1.619 (True: -1.6)
# Final Estimated c: 3.282 (True: 3.5)
# Final Estimated d: -1.262 (True: -1.2)

# %%
# 1. Initialize the Adam optimizer
# Only need one base learning rate now. Adam automatically scales the actual rate based on their historical gradient variance.
base_learning_rate = 0.1
optimizer = optax.adam(learning_rate=base_learning_rate)

# 2. Initialize the optimizer state
# Optax is pure functional. It does not store state internally. 
# We must explicitly create and pass the 'opt_state' which holds the momentum and variance trackers for our specific parameters.
opt_state = optimizer.init(current_params)

# Fixed seed for the optimization forward passes to isolate parameter gradients from SDE noise
opt_key = jax.random.PRNGKey(42)

for i in range(1000): 
    
    # Calculate Loss and EXACT Gradients
    loss, grads = loss_and_grad_fn(current_params, fixed_params, target_data, opt_key)
    
    # 3. Calculate updates using Optax
    # We pass the raw gradients and the current optimizer state. 
    # Optax returns the mathematically scaled updates and a newly updated state.
    updates, opt_state = optimizer.update(grads, opt_state)
    
    # 4. Apply updates to the parameters
    # This replaces the manual `current_params['c'] -= lr * grad_c`
    current_params = optax.apply_updates(current_params, updates)

    # 5. Apply physical constraints
    # JAX arrays require jnp.maximum instead of Python's built-in max()
    current_params['c'] = jnp.maximum(current_params['c'], 0.001)

    # Cutoff condition
    if loss < 0.0001:
        break
    
    # We use float() or .item() to format JAX arrays into standard Python floats for printing
    print(f"Iter {i}: Loss={loss:.5f}")
    print(f"    Grad a={grads['a']:.4f} -> Update a to {float(current_params['a']):.3f}")
    print(f"    Grad b={grads['b']:.4f} -> Update b to {float(current_params['b']):.3f}")
    print(f"    Grad c={grads['c']:.4f} -> Update c to {float(current_params['c']):.3f}")
    print(f"    Grad d={grads['d']:.4f} -> Update d to {float(current_params['d']):.3f}")

print(f"Final Estimated a: {float(current_params['a']):.3f} (True: {target_params['a']})")
print(f"Final Estimated b: {float(current_params['b']):.3f} (True: {target_params['b']})")
print(f"Final Estimated c: {float(current_params['c']):.3f} (True: {target_params['c']})")
print(f"Final Estimated d: {float(current_params['d']):.3f} (True: {target_params['d']})")
# Out:
# Iter 0: Loss=0.00302
#     Grad a=0.0187 -> Update a to -0.069
#     Grad b=0.0091 -> Update b to -1.719
#     Grad c=-0.0063 -> Update c to 3.382
#     Grad d=0.0087 -> Update d to -1.362
# Iter 1: Loss=0.01148
#     Grad a=-0.0799 -> Update a to -0.011
#     Grad b=-0.0488 -> Update b to -1.659
#     Grad c=0.0290 -> Update c to 3.324
#     Grad d=-0.0464 -> Update d to -1.301
# Iter 2: Loss=0.00346
#     Grad a=-0.0244 -> Update a to 0.049
#     Grad b=-0.0162 -> Update b to -1.594
#     Grad c=0.0090 -> Update c to 3.262
#     Grad d=-0.0146 -> Update d to -1.238
# Iter 3: Loss=0.00446
#     Grad a=0.0376 -> Update a to 0.071
#     Grad b=0.0203 -> Update b to -1.566
#     Grad c=-0.0133 -> Update c to 3.238
#     Grad d=0.0201 -> Update d to -1.211
# Iter 4: Loss=0.00730
#     Grad a=0.0554 -> Update a to 0.060
#     Grad b=0.0310 -> Update b to -1.571
#     Grad c=-0.0201 -> Update c to 3.249
#     Grad d=0.0319 -> Update d to -1.220
# Iter 5: Loss=0.00606
#     Grad a=0.0486 -> Update a to 0.029
#     Grad b=0.0272 -> Update b to -1.596
#     Grad c=-0.0175 -> Update c to 3.279
#     Grad d=0.0276 -> Update d to -1.248
# Iter 6: Loss=0.00341
#     Grad a=0.0253 -> Update a to -0.008
#     Grad b=0.0140 -> Update b to -1.628
#     Grad c=-0.0088 -> Update c to 3.315
#     Grad d=0.0137 -> Update d to -1.282
# Iter 7: Loss=0.00278
#     Grad a=-0.0107 -> Update a to -0.036
#     Grad b=-0.0067 -> Update b to -1.650
#     Grad c=0.0040 -> Update c to 3.341
#     Grad d=-0.0058 -> Update d to -1.308
# Iter 8: Loss=0.00435
#     Grad a=-0.0358 -> Update a to -0.045
#     Grad b=-0.0228 -> Update b to -1.655
#     Grad c=0.0132 -> Update c to 3.350
#     Grad d=-0.0208 -> Update d to -1.316
# Iter 9: Loss=0.00516
#     Grad a=-0.0438 -> Update a to -0.038
#     Grad b=-0.0276 -> Update b to -1.642
#     Grad c=0.0161 -> Update c to 3.341
#     Grad d=-0.0254 -> Update d to -1.307
# Iter 10: Loss=0.00421
#     Grad a=-0.0344 -> Update a to -0.020
#     Grad b=-0.0216 -> Update b to -1.618
#     Grad c=0.0128 -> Update c to 3.322
#     Grad d=-0.0200 -> Update d to -1.286
# Iter 11: Loss=0.00292
#     Grad a=-0.0149 -> Update a to 0.002
#     Grad b=-0.0087 -> Update b to -1.591
#     Grad c=0.0058 -> Update c to 3.298
#     Grad d=-0.0082 -> Update d to -1.263
# Iter 12: Loss=0.00274
#     Grad a=0.0087 -> Update a to 0.018
#     Grad b=0.0059 -> Update b to -1.571
#     Grad c=-0.0027 -> Update c to 3.280
#     Grad d=0.0051 -> Update d to -1.246
# Iter 13: Loss=0.00355
#     Grad a=0.0265 -> Update a to 0.024
#     Grad b=0.0162 -> Update b to -1.562
#     Grad c=-0.0090 -> Update c to 3.272
#     Grad d=0.0148 -> Update d to -1.239
# Iter 14: Loss=0.00407
#     Grad a=0.0326 -> Update a to 0.018
#     Grad b=0.0198 -> Update b to -1.565
#     Grad c=-0.0113 -> Update c to 3.276
#     Grad d=0.0183 -> Update d to -1.243
# Iter 15: Loss=0.00371
#     Grad a=0.0283 -> Update a to 0.003
#     Grad b=0.0174 -> Update b to -1.578
#     Grad c=-0.0098 -> Update c to 3.288
#     Grad d=0.0161 -> Update d to -1.257
# Iter 16: Loss=0.00296
#     Grad a=0.0152 -> Update a to -0.015
#     Grad b=0.0100 -> Update b to -1.595
#     Grad c=-0.0051 -> Update c to 3.303
#     Grad d=0.0090 -> Update d to -1.274
# Iter 17: Loss=0.00266
#     Grad a=-0.0026 -> Update a to -0.031
#     Grad b=-0.0006 -> Update b to -1.610
#     Grad c=0.0012 -> Update c to 3.316
#     Grad d=-0.0006 -> Update d to -1.289
# Iter 18: Loss=0.00302
#     Grad a=-0.0172 -> Update a to -0.039
#     Grad b=-0.0100 -> Update b to -1.618
#     Grad c=0.0065 -> Update c to 3.322
#     Grad d=-0.0091 -> Update d to -1.298
# Iter 19: Loss=0.00344
#     Grad a=-0.0247 -> Update a to -0.038
#     Grad b=-0.0150 -> Update b to -1.616
#     Grad c=0.0093 -> Update c to 3.318
#     Grad d=-0.0137 -> Update d to -1.298
# Iter 20: Loss=0.00336
#     Grad a=-0.0236 -> Update a to -0.030
#     Grad b=-0.0143 -> Update b to -1.607
#     Grad c=0.0088 -> Update c to 3.307
#     Grad d=-0.0130 -> Update d to -1.290
# Iter 21: Loss=0.00293
#     Grad a=-0.0152 -> Update a to -0.017
#     Grad b=-0.0088 -> Update b to -1.594
#     Grad c=0.0057 -> Update c to 3.291
#     Grad d=-0.0079 -> Update d to -1.278
# Iter 22: Loss=0.00265
#     Grad a=-0.0025 -> Update a to -0.005
#     Grad b=-0.0006 -> Update b to -1.582
#     Grad c=0.0010 -> Update c to 3.276
#     Grad d=-0.0005 -> Update d to -1.267
# Iter 23: Loss=0.00279
#     Grad a=0.0104 -> Update a to 0.003
#     Grad b=0.0070 -> Update b to -1.574
#     Grad c=-0.0037 -> Update c to 3.266
#     Grad d=0.0065 -> Update d to -1.261
# Iter 24: Loss=0.00308
#     Grad a=0.0183 -> Update a to 0.004
#     Grad b=0.0115 -> Update b to -1.575
#     Grad c=-0.0065 -> Update c to 3.263
#     Grad d=0.0105 -> Update d to -1.261
# Iter 25: Loss=0.00310
#     Grad a=0.0189 -> Update a to -0.002
#     Grad b=0.0117 -> Update b to -1.581
#     Grad c=-0.0068 -> Update c to 3.267
#     Grad d=0.0108 -> Update d to -1.269
# Iter 26: Loss=0.00285
#     Grad a=0.0128 -> Update a to -0.012
#     Grad b=0.0082 -> Update b to -1.592
#     Grad c=-0.0046 -> Update c to 3.274
#     Grad d=0.0074 -> Update d to -1.280
# Iter 27: Loss=0.00265
#     Grad a=0.0025 -> Update a to -0.021
#     Grad b=0.0020 -> Update b to -1.604
#     Grad c=-0.0009 -> Update c to 3.282
#     Grad d=0.0018 -> Update d to -1.291
# Iter 28: Loss=0.00271
#     Grad a=-0.0078 -> Update a to -0.028
#     Grad b=-0.0044 -> Update b to -1.611
#     Grad c=0.0029 -> Update c to 3.287
#     Grad d=-0.0040 -> Update d to -1.299
# Iter 29: Loss=0.00289
#     Grad a=-0.0142 -> Update a to -0.028
#     Grad b=-0.0086 -> Update b to -1.613
#     Grad c=0.0053 -> Update c to 3.285
#     Grad d=-0.0078 -> Update d to -1.301
# Iter 30: Loss=0.00292
#     Grad a=-0.0150 -> Update a to -0.023
#     Grad b=-0.0091 -> Update b to -1.609
#     Grad c=0.0056 -> Update c to 3.279
#     Grad d=-0.0084 -> Update d to -1.297
# Iter 31: Loss=0.00277
#     Grad a=-0.0103 -> Update a to -0.014
#     Grad b=-0.0062 -> Update b to -1.602
#     Grad c=0.0038 -> Update c to 3.268
#     Grad d=-0.0058 -> Update d to -1.291
# Iter 32: Loss=0.00264
#     Grad a=-0.0021 -> Update a to -0.006
#     Grad b=-0.0012 -> Update b to -1.594
#     Grad c=0.0008 -> Update c to 3.259
#     Grad d=-0.0012 -> Update d to -1.283
# Iter 33: Loss=0.00269
#     Grad a=0.0065 -> Update a to -0.001
#     Grad b=0.0038 -> Update b to -1.590
#     Grad c=-0.0024 -> Update c to 3.252
#     Grad d=0.0033 -> Update d to -1.279
# Iter 34: Loss=0.00280
#     Grad a=0.0118 -> Update a to -0.001
#     Grad b=0.0068 -> Update b to -1.590
#     Grad c=-0.0043 -> Update c to 3.251
#     Grad d=0.0060 -> Update d to -1.279
# Iter 35: Loss=0.00281
#     Grad a=0.0120 -> Update a to -0.005
#     Grad b=0.0069 -> Update b to -1.595
#     Grad c=-0.0044 -> Update c to 3.254
#     Grad d=0.0062 -> Update d to -1.284
# Iter 36: Loss=0.00270
#     Grad a=0.0075 -> Update a to -0.012
#     Grad b=0.0043 -> Update b to -1.602
#     Grad c=-0.0029 -> Update c to 3.260
#     Grad d=0.0038 -> Update d to -1.290
# Iter 37: Loss=0.00264
#     Grad a=0.0005 -> Update a to -0.018
#     Grad b=0.0001 -> Update b to -1.608
#     Grad c=-0.0003 -> Update c to 3.266
#     Grad d=0.0001 -> Update d to -1.296
# Iter 38: Loss=0.00268
#     Grad a=-0.0061 -> Update a to -0.022
#     Grad b=-0.0039 -> Update b to -1.611
#     Grad c=0.0021 -> Update c to 3.269
#     Grad d=-0.0034 -> Update d to -1.299
# Iter 39: Loss=0.00275
#     Grad a=-0.0095 -> Update a to -0.021
#     Grad b=-0.0060 -> Update b to -1.610
#     Grad c=0.0033 -> Update c to 3.268
#     Grad d=-0.0052 -> Update d to -1.298
# Iter 40: Loss=0.00273
#     Grad a=-0.0087 -> Update a to -0.017
#     Grad b=-0.0055 -> Update b to -1.606
#     Grad c=0.0030 -> Update c to 3.264
#     Grad d=-0.0048 -> Update d to -1.294
# Iter 41: Loss=0.00266
#     Grad a=-0.0044 -> Update a to -0.011
#     Grad b=-0.0028 -> Update b to -1.600
#     Grad c=0.0014 -> Update c to 3.259
#     Grad d=-0.0024 -> Update d to -1.289
# Iter 42: Loss=0.00264
#     Grad a=0.0014 -> Update a to -0.007
#     Grad b=0.0007 -> Update b to -1.595
#     Grad c=-0.0007 -> Update c to 3.255
#     Grad d=0.0007 -> Update d to -1.284
# Iter 43: Loss=0.00268
#     Grad a=0.0062 -> Update a to -0.006
#     Grad b=0.0036 -> Update b to -1.593
#     Grad c=-0.0024 -> Update c to 3.254
#     Grad d=0.0032 -> Update d to -1.283
# Iter 44: Loss=0.00271
#     Grad a=0.0078 -> Update a to -0.007
#     Grad b=0.0046 -> Update b to -1.594
#     Grad c=-0.0030 -> Update c to 3.257
#     Grad d=0.0041 -> Update d to -1.284
# Iter 45: Loss=0.00268
#     Grad a=0.0059 -> Update a to -0.012
#     Grad b=0.0035 -> Update b to -1.598
#     Grad c=-0.0023 -> Update c to 3.262
#     Grad d=0.0031 -> Update d to -1.288
# Iter 46: Loss=0.00264
#     Grad a=0.0016 -> Update a to -0.016
#     Grad b=0.0010 -> Update b to -1.602
#     Grad c=-0.0007 -> Update c to 3.267
#     Grad d=0.0008 -> Update d to -1.292
# Iter 47: Loss=0.00265
#     Grad a=-0.0030 -> Update a to -0.019
#     Grad b=-0.0018 -> Update b to -1.604
#     Grad c=0.0010 -> Update c to 3.271
#     Grad d=-0.0017 -> Update d to -1.294
# Iter 48: Loss=0.00268
#     Grad a=-0.0058 -> Update a to -0.019
#     Grad b=-0.0035 -> Update b to -1.604
#     Grad c=0.0021 -> Update c to 3.271
#     Grad d=-0.0032 -> Update d to -1.294
# Iter 49: Loss=0.00268
#     Grad a=-0.0058 -> Update a to -0.017
#     Grad b=-0.0034 -> Update b to -1.601
#     Grad c=0.0021 -> Update c to 3.269
#     Grad d=-0.0032 -> Update d to -1.291
# Iter 50: Loss=0.00265
#     Grad a=-0.0032 -> Update a to -0.013
#     Grad b=-0.0018 -> Update b to -1.597
#     Grad c=0.0011 -> Update c to 3.266
#     Grad d=-0.0017 -> Update d to -1.287
# Iter 51: Loss=0.00264
#     Grad a=0.0006 -> Update a to -0.010
#     Grad b=0.0006 -> Update b to -1.594
#     Grad c=-0.0002 -> Update c to 3.264
#     Grad d=0.0004 -> Update d to -1.284
# Iter 52: Loss=0.00266
#     Grad a=0.0038 -> Update a to -0.009
#     Grad b=0.0025 -> Update b to -1.593
#     Grad c=-0.0014 -> Update c to 3.263
#     Grad d=0.0021 -> Update d to -1.283
# Iter 53: Loss=0.00267
#     Grad a=0.0049 -> Update a to -0.010
#     Grad b=0.0031 -> Update b to -1.594
#     Grad c=-0.0018 -> Update c to 3.265
#     Grad d=0.0027 -> Update d to -1.284
# Iter 54: Loss=0.00265
#     Grad a=0.0035 -> Update a to -0.013
#     Grad b=0.0023 -> Update b to -1.597
#     Grad c=-0.0013 -> Update c to 3.268
#     Grad d=0.0019 -> Update d to -1.286
# Iter 55: Loss=0.00264
#     Grad a=0.0005 -> Update a to -0.016
#     Grad b=0.0005 -> Update b to -1.601
#     Grad c=-0.0002 -> Update c to 3.271
#     Grad d=0.0004 -> Update d to -1.289
# Iter 56: Loss=0.00264
#     Grad a=-0.0025 -> Update a to -0.017
#     Grad b=-0.0013 -> Update b to -1.603
#     Grad c=0.0009 -> Update c to 3.273
#     Grad d=-0.0012 -> Update d to -1.290
# Iter 57: Loss=0.00265
#     Grad a=-0.0040 -> Update a to -0.016
#     Grad b=-0.0023 -> Update b to -1.602
#     Grad c=0.0014 -> Update c to 3.273
#     Grad d=-0.0021 -> Update d to -1.290
# Iter 58: Loss=0.00265
#     Grad a=-0.0035 -> Update a to -0.014
#     Grad b=-0.0020 -> Update b to -1.601
#     Grad c=0.0013 -> Update c to 3.271
#     Grad d=-0.0018 -> Update d to -1.288
# Iter 59: Loss=0.00264
#     Grad a=-0.0014 -> Update a to -0.011
#     Grad b=-0.0007 -> Update b to -1.599
#     Grad c=0.0005 -> Update c to 3.269
#     Grad d=-0.0007 -> Update d to -1.285
# Iter 60: Loss=0.00264
#     Grad a=0.0012 -> Update a to -0.009
#     Grad b=0.0008 -> Update b to -1.597
#     Grad c=-0.0005 -> Update c to 3.267
#     Grad d=0.0007 -> Update d to -1.284
# Iter 61: Loss=0.00265
#     Grad a=0.0029 -> Update a to -0.009
#     Grad b=0.0018 -> Update b to -1.598
#     Grad c=-0.0011 -> Update c to 3.267
#     Grad d=0.0016 -> Update d to -1.284
# Iter 62: Loss=0.00265
#     Grad a=0.0030 -> Update a to -0.010
#     Grad b=0.0019 -> Update b to -1.600
#     Grad c=-0.0011 -> Update c to 3.269
#     Grad d=0.0016 -> Update d to -1.285
# Iter 63: Loss=0.00264
#     Grad a=0.0015 -> Update a to -0.012
#     Grad b=0.0009 -> Update b to -1.602
#     Grad c=-0.0006 -> Update c to 3.271
#     Grad d=0.0008 -> Update d to -1.287
# Iter 64: Loss=0.00264
#     Grad a=-0.0006 -> Update a to -0.013
#     Grad b=-0.0003 -> Update b to -1.604
#     Grad c=0.0002 -> Update c to 3.272
#     Grad d=-0.0003 -> Update d to -1.289
# Iter 65: Loss=0.00264
#     Grad a=-0.0022 -> Update a to -0.013
#     Grad b=-0.0013 -> Update b to -1.605
#     Grad c=0.0008 -> Update c to 3.273
#     Grad d=-0.0012 -> Update d to -1.289
# Iter 66: Loss=0.00264
#     Grad a=-0.0025 -> Update a to -0.012
#     Grad b=-0.0015 -> Update b to -1.604
#     Grad c=0.0009 -> Update c to 3.272
#     Grad d=-0.0014 -> Update d to -1.288
# Iter 67: Loss=0.00264
#     Grad a=-0.0015 -> Update a to -0.010
#     Grad b=-0.0009 -> Update b to -1.602
#     Grad c=0.0005 -> Update c to 3.270
#     Grad d=-0.0008 -> Update d to -1.286
# Iter 68: Loss=0.00264
#     Grad a=0.0003 -> Update a to -0.008
#     Grad b=0.0001 -> Update b to -1.601
#     Grad c=-0.0001 -> Update c to 3.269
#     Grad d=0.0001 -> Update d to -1.285
# Iter 69: Loss=0.00264
#     Grad a=0.0018 -> Update a to -0.008
#     Grad b=0.0010 -> Update b to -1.601
#     Grad c=-0.0007 -> Update c to 3.269
#     Grad d=0.0009 -> Update d to -1.284
# Iter 70: Loss=0.00264
#     Grad a=0.0021 -> Update a to -0.009
#     Grad b=0.0012 -> Update b to -1.602
#     Grad c=-0.0008 -> Update c to 3.270
#     Grad d=0.0011 -> Update d to -1.285
# Iter 71: Loss=0.00264
#     Grad a=0.0014 -> Update a to -0.010
#     Grad b=0.0007 -> Update b to -1.603
#     Grad c=-0.0005 -> Update c to 3.271
#     Grad d=0.0007 -> Update d to -1.286
# Iter 72: Loss=0.00264
#     Grad a=-0.0001 -> Update a to -0.011
#     Grad b=-0.0001 -> Update b to -1.605
#     Grad c=0.0000 -> Update c to 3.273
#     Grad d=-0.0001 -> Update d to -1.287
# Iter 73: Loss=0.00264
#     Grad a=-0.0013 -> Update a to -0.011
#     Grad b=-0.0009 -> Update b to -1.605
#     Grad c=0.0005 -> Update c to 3.273
#     Grad d=-0.0007 -> Update d to -1.287
# Iter 74: Loss=0.00264
#     Grad a=-0.0017 -> Update a to -0.011
#     Grad b=-0.0011 -> Update b to -1.604
#     Grad c=0.0006 -> Update c to 3.273
#     Grad d=-0.0009 -> Update d to -1.287
# Iter 75: Loss=0.00264
#     Grad a=-0.0011 -> Update a to -0.010
#     Grad b=-0.0007 -> Update b to -1.603
#     Grad c=0.0004 -> Update c to 3.272
#     Grad d=-0.0006 -> Update d to -1.285
# Iter 76: Loss=0.00264
#     Grad a=0.0001 -> Update a to -0.009
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.271
#     Grad d=0.0000 -> Update d to -1.284
# Iter 77: Loss=0.00264
#     Grad a=0.0011 -> Update a to -0.008
#     Grad b=0.0006 -> Update b to -1.602
#     Grad c=-0.0004 -> Update c to 3.271
#     Grad d=0.0006 -> Update d to -1.284
# Iter 78: Loss=0.00264
#     Grad a=0.0014 -> Update a to -0.009
#     Grad b=0.0008 -> Update b to -1.602
#     Grad c=-0.0005 -> Update c to 3.272
#     Grad d=0.0008 -> Update d to -1.285
# Iter 79: Loss=0.00264
#     Grad a=0.0009 -> Update a to -0.010
#     Grad b=0.0005 -> Update b to -1.603
#     Grad c=-0.0003 -> Update c to 3.273
#     Grad d=0.0005 -> Update d to -1.285
# Iter 80: Loss=0.00264
#     Grad a=-0.0001 -> Update a to -0.011
#     Grad b=-0.0001 -> Update b to -1.604
#     Grad c=0.0001 -> Update c to 3.274
#     Grad d=-0.0001 -> Update d to -1.286
# Iter 81: Loss=0.00264
#     Grad a=-0.0009 -> Update a to -0.011
#     Grad b=-0.0006 -> Update b to -1.604
#     Grad c=0.0004 -> Update c to 3.274
#     Grad d=-0.0005 -> Update d to -1.286
# Iter 82: Loss=0.00264
#     Grad a=-0.0011 -> Update a to -0.011
#     Grad b=-0.0007 -> Update b to -1.603
#     Grad c=0.0004 -> Update c to 3.274
#     Grad d=-0.0006 -> Update d to -1.286
# Iter 83: Loss=0.00264
#     Grad a=-0.0007 -> Update a to -0.010
#     Grad b=-0.0004 -> Update b to -1.602
#     Grad c=0.0003 -> Update c to 3.273
#     Grad d=-0.0003 -> Update d to -1.285
# Iter 84: Loss=0.00264
#     Grad a=0.0002 -> Update a to -0.009
#     Grad b=0.0001 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.273
#     Grad d=0.0001 -> Update d to -1.284
# Iter 85: Loss=0.00264
#     Grad a=0.0008 -> Update a to -0.009
#     Grad b=0.0005 -> Update b to -1.602
#     Grad c=-0.0003 -> Update c to 3.273
#     Grad d=0.0005 -> Update d to -1.284
# Iter 86: Loss=0.00264
#     Grad a=0.0009 -> Update a to -0.010
#     Grad b=0.0006 -> Update b to -1.602
#     Grad c=-0.0003 -> Update c to 3.273
#     Grad d=0.0005 -> Update d to -1.285
# Iter 87: Loss=0.00264
#     Grad a=0.0004 -> Update a to -0.010
#     Grad b=0.0003 -> Update b to -1.603
#     Grad c=-0.0001 -> Update c to 3.274
#     Grad d=0.0003 -> Update d to -1.285
# Iter 88: Loss=0.00264
#     Grad a=-0.0003 -> Update a to -0.011
#     Grad b=-0.0001 -> Update b to -1.603
#     Grad c=0.0001 -> Update c to 3.274
#     Grad d=-0.0001 -> Update d to -1.286
# Iter 89: Loss=0.00264
#     Grad a=-0.0007 -> Update a to -0.011
#     Grad b=-0.0004 -> Update b to -1.603
#     Grad c=0.0003 -> Update c to 3.274
#     Grad d=-0.0004 -> Update d to -1.286
# Iter 90: Loss=0.00264
#     Grad a=-0.0007 -> Update a to -0.010
#     Grad b=-0.0004 -> Update b to -1.603
#     Grad c=0.0003 -> Update c to 3.273
#     Grad d=-0.0004 -> Update d to -1.286
# Iter 91: Loss=0.00264
#     Grad a=-0.0003 -> Update a to -0.010
#     Grad b=-0.0002 -> Update b to -1.602
#     Grad c=0.0001 -> Update c to 3.273
#     Grad d=-0.0001 -> Update d to -1.285
# Iter 92: Loss=0.00264
#     Grad a=0.0003 -> Update a to -0.009
#     Grad b=0.0002 -> Update b to -1.602
#     Grad c=-0.0001 -> Update c to 3.272
#     Grad d=0.0002 -> Update d to -1.285
# Iter 93: Loss=0.00264
#     Grad a=0.0006 -> Update a to -0.009
#     Grad b=0.0004 -> Update b to -1.602
#     Grad c=-0.0002 -> Update c to 3.272
#     Grad d=0.0003 -> Update d to -1.285
# Iter 94: Loss=0.00264
#     Grad a=0.0005 -> Update a to -0.010
#     Grad b=0.0003 -> Update b to -1.603
#     Grad c=-0.0002 -> Update c to 3.272
#     Grad d=0.0003 -> Update d to -1.285
# Iter 95: Loss=0.00264
#     Grad a=0.0001 -> Update a to -0.010
#     Grad b=0.0001 -> Update b to -1.603
#     Grad c=-0.0000 -> Update c to 3.273
#     Grad d=0.0001 -> Update d to -1.286
# Iter 96: Loss=0.00264
#     Grad a=-0.0003 -> Update a to -0.010
#     Grad b=-0.0002 -> Update b to -1.603
#     Grad c=0.0001 -> Update c to 3.273
#     Grad d=-0.0002 -> Update d to -1.286
# Iter 97: Loss=0.00264
#     Grad a=-0.0005 -> Update a to -0.010
#     Grad b=-0.0003 -> Update b to -1.603
#     Grad c=0.0002 -> Update c to 3.273
#     Grad d=-0.0003 -> Update d to -1.286
# Iter 98: Loss=0.00264
#     Grad a=-0.0003 -> Update a to -0.010
#     Grad b=-0.0002 -> Update b to -1.603
#     Grad c=0.0001 -> Update c to 3.272
#     Grad d=-0.0002 -> Update d to -1.286
# Iter 99: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.285
# Iter 100: Loss=0.00264
#     Grad a=0.0004 -> Update a to -0.010
#     Grad b=0.0002 -> Update b to -1.602
#     Grad c=-0.0001 -> Update c to 3.272
#     Grad d=0.0002 -> Update d to -1.285
# Iter 101: Loss=0.00264
#     Grad a=0.0004 -> Update a to -0.010
#     Grad b=0.0002 -> Update b to -1.603
#     Grad c=-0.0002 -> Update c to 3.272
#     Grad d=0.0002 -> Update d to -1.285
# Iter 102: Loss=0.00264
#     Grad a=0.0002 -> Update a to -0.010
#     Grad b=0.0001 -> Update b to -1.603
#     Grad c=-0.0001 -> Update c to 3.272
#     Grad d=0.0001 -> Update d to -1.286
# Iter 103: Loss=0.00264
#     Grad a=-0.0001 -> Update a to -0.010
#     Grad b=-0.0001 -> Update b to -1.603
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0001 -> Update d to -1.286
# Iter 104: Loss=0.00264
#     Grad a=-0.0003 -> Update a to -0.010
#     Grad b=-0.0002 -> Update b to -1.603
#     Grad c=0.0001 -> Update c to 3.272
#     Grad d=-0.0002 -> Update d to -1.286
# Iter 105: Loss=0.00264
#     Grad a=-0.0003 -> Update a to -0.010
#     Grad b=-0.0002 -> Update b to -1.603
#     Grad c=0.0001 -> Update c to 3.272
#     Grad d=-0.0002 -> Update d to -1.286
# Iter 106: Loss=0.00264
#     Grad a=-0.0001 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 107: Loss=0.00264
#     Grad a=0.0002 -> Update a to -0.010
#     Grad b=0.0001 -> Update b to -1.602
#     Grad c=-0.0001 -> Update c to 3.272
#     Grad d=0.0001 -> Update d to -1.285
# Iter 108: Loss=0.00264
#     Grad a=0.0003 -> Update a to -0.010
#     Grad b=0.0002 -> Update b to -1.602
#     Grad c=-0.0001 -> Update c to 3.272
#     Grad d=0.0002 -> Update d to -1.286
# Iter 109: Loss=0.00264
#     Grad a=0.0002 -> Update a to -0.010
#     Grad b=0.0001 -> Update b to -1.602
#     Grad c=-0.0001 -> Update c to 3.272
#     Grad d=0.0001 -> Update d to -1.286
# Iter 110: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.603
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 111: Loss=0.00264
#     Grad a=-0.0002 -> Update a to -0.011
#     Grad b=-0.0001 -> Update b to -1.603
#     Grad c=0.0001 -> Update c to 3.272
#     Grad d=-0.0001 -> Update d to -1.286
# Iter 112: Loss=0.00264
#     Grad a=-0.0002 -> Update a to -0.010
#     Grad b=-0.0001 -> Update b to -1.602
#     Grad c=0.0001 -> Update c to 3.272
#     Grad d=-0.0001 -> Update d to -1.286
# Iter 113: Loss=0.00264
#     Grad a=-0.0001 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 114: Loss=0.00264
#     Grad a=0.0001 -> Update a to -0.010
#     Grad b=0.0001 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0001 -> Update d to -1.286
# Iter 115: Loss=0.00264
#     Grad a=0.0002 -> Update a to -0.010
#     Grad b=0.0001 -> Update b to -1.602
#     Grad c=-0.0001 -> Update c to 3.272
#     Grad d=0.0001 -> Update d to -1.286
# Iter 116: Loss=0.00264
#     Grad a=0.0002 -> Update a to -0.010
#     Grad b=0.0001 -> Update b to -1.602
#     Grad c=-0.0001 -> Update c to 3.272
#     Grad d=0.0001 -> Update d to -1.286
# Iter 117: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.603
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 118: Loss=0.00264
#     Grad a=-0.0001 -> Update a to -0.010
#     Grad b=-0.0001 -> Update b to -1.603
#     Grad c=0.0001 -> Update c to 3.272
#     Grad d=-0.0001 -> Update d to -1.286
# Iter 119: Loss=0.00264
#     Grad a=-0.0002 -> Update a to -0.010
#     Grad b=-0.0001 -> Update b to -1.602
#     Grad c=0.0001 -> Update c to 3.272
#     Grad d=-0.0001 -> Update d to -1.286
# Iter 120: Loss=0.00264
#     Grad a=-0.0001 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 121: Loss=0.00264
#     Grad a=0.0001 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 122: Loss=0.00264
#     Grad a=0.0001 -> Update a to -0.010
#     Grad b=0.0001 -> Update b to -1.602
#     Grad c=-0.0001 -> Update c to 3.272
#     Grad d=0.0001 -> Update d to -1.286
# Iter 123: Loss=0.00264
#     Grad a=0.0001 -> Update a to -0.010
#     Grad b=0.0001 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0001 -> Update d to -1.286
# Iter 124: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.603
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 125: Loss=0.00264
#     Grad a=-0.0001 -> Update a to -0.010
#     Grad b=-0.0001 -> Update b to -1.603
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0001 -> Update d to -1.286
# Iter 126: Loss=0.00264
#     Grad a=-0.0001 -> Update a to -0.010
#     Grad b=-0.0001 -> Update b to -1.603
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0001 -> Update d to -1.286
# Iter 127: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 128: Loss=0.00264
#     Grad a=0.0001 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 129: Loss=0.00264
#     Grad a=0.0001 -> Update a to -0.010
#     Grad b=0.0001 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0001 -> Update d to -1.286
# Iter 130: Loss=0.00264
#     Grad a=0.0001 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 131: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.603
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 132: Loss=0.00264
#     Grad a=-0.0001 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.603
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 133: Loss=0.00264
#     Grad a=-0.0001 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 134: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 135: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 136: Loss=0.00264
#     Grad a=0.0001 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 137: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 138: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.603
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 139: Loss=0.00264
#     Grad a=-0.0001 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.603
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 140: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 141: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 142: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 143: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 144: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.603
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 145: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.603
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 146: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.603
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 147: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.603
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 148: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 149: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.603
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 150: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.603
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 151: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.603
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 152: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.603
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 153: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.603
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 154: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.603
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 155: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 156: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 157: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.603
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 158: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.603
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 159: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.603
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 160: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 161: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 162: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 163: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 164: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.603
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 165: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.603
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 166: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 167: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 168: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 169: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 170: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.603
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 171: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.603
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 172: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.603
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 173: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 174: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 175: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 176: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.603
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 177: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.603
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 178: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.603
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 179: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 180: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 181: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 182: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 183: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 184: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 185: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 186: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 187: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 188: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 189: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 190: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.603
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 191: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 192: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 193: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 194: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 195: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.603
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 196: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.603
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 197: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.603
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 198: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 199: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 200: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 201: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.603
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 202: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.603
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 203: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 204: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 205: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 206: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 207: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 208: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 209: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 210: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 211: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 212: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 213: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 214: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 215: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 216: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 217: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 218: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 219: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 220: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 221: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 222: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 223: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 224: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 225: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 226: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 227: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 228: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 229: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 230: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 231: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 232: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 233: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 234: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 235: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 236: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 237: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 238: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 239: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 240: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 241: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 242: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 243: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 244: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 245: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 246: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 247: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 248: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 249: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 250: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 251: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 252: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 253: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 254: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 255: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 256: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 257: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 258: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 259: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 260: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 261: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
# ...
# Iter 914: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 915: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 916: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 917: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 918: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 919: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 920: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 921: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 922: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 923: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 924: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 925: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 926: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 927: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 928: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 929: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 930: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 931: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 932: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 933: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 934: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 935: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 936: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 937: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 938: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 939: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 940: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 941: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 942: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 943: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 944: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 945: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 946: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 947: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 948: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 949: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 950: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 951: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 952: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 953: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 954: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 955: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 956: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 957: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 958: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 959: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 960: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 961: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 962: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 963: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 964: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 965: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 966: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 967: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 968: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 969: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 970: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 971: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 972: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 973: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 974: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 975: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 976: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 977: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 978: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 979: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 980: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 981: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 982: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 983: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 984: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 985: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 986: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 987: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 988: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 989: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 990: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 991: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 992: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 993: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 994: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 995: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 996: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 997: Loss=0.00264
#     Grad a=-0.0000 -> Update a to -0.010
#     Grad b=-0.0000 -> Update b to -1.602
#     Grad c=0.0000 -> Update c to 3.272
#     Grad d=-0.0000 -> Update d to -1.286
# Iter 998: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Iter 999: Loss=0.00264
#     Grad a=0.0000 -> Update a to -0.010
#     Grad b=0.0000 -> Update b to -1.602
#     Grad c=-0.0000 -> Update c to 3.272
#     Grad d=0.0000 -> Update d to -1.286
# Final Estimated a: -0.010 (True: 0)
# Final Estimated b: -1.602 (True: -1.6)
# Final Estimated c: 3.272 (True: 3.5)
# Final Estimated d: -1.286 (True: -1.2)
