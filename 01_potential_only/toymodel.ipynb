# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm



PARAMS = {
    'a': 0,      # Bifurcation point (y=0)
    'b': 0.2,    # x-scale stability, distance between branches^-1
    'c': 3,      # Drive strength (tilt), distance between bifurcation and new stable points
    'd': 0.2     # Wall steepness
}

# Simulation controls
N_PARTICLES = 1000
T_TOTAL = 2          # Total duration
dt = 0.01            # Time step size
n_steps = int(T_TOTAL / dt)
sigma = 0.2          # Noise
x0 = 0.0             # Initial x position (near the unstable point)
dx = 0.05            # Initial noise scale for x
y0 = -1.0            # Initial y position (before bifurcation)
dy = 0.05            # Initial noise scale for y



# initialize particles
particles_x = np.random.normal(x0, dx, N_PARTICLES)
particles_y = np.random.normal(y0, dy, N_PARTICLES)

def potential(x, y, p):
    """ H= -(y - a)x^2 + b x^4 - c y + d y^4 """
    return -(y - p['a']) * (x**2) + p['b'] * (x**4) - p['c'] * y + p['d'] * (y**4)

def force(x, y, p):
    """
    Fx = -dH/dx, Fy = -dH/dy
    """
    # Force in x: 2(y-a)x - 4bx^3
    fx = 2 * (y - p['a']) * x - 4 * p['b'] * (x**3)
    
    # Force in y: x^2 + c - 4dy^3
    fy = (x**2) + p['c'] - 4 * p['d'] * (y**3)
    
    return fx, fy

# --- Plot Setup ---

x = np.linspace(-5, 5, 200)
y = np.linspace(-2, 4, 200)
X, Y = np.meshgrid(x, y)
Z = potential(X, Y, p=PARAMS)

# --- Plotting ---

fig = plt.figure(figsize=(10, 5))

# Subplot 1: 3D Surface Plot
ax1 = fig.add_subplot(1, 2, 1, projection='3d')
surf = ax1.plot_surface(X, Y, Z, cmap=cm.viridis, alpha=0.9, edgecolor='none')
ax1.set_title("2D Landscape", fontsize=14)
ax1.set_xlabel("x")
ax1.set_ylabel("y")
ax1.set_zlabel("$\phi$")
# Adjust view angle to see the branching clearly
ax1.view_init(elev=30, azim=160) 

# Subplot 2: Contour Plot (Top-down view)
ax2 = fig.add_subplot(1, 2, 2)
contour = ax2.contourf(X, Y, Z, levels=30, cmap=cm.viridis)
ax2.set_title("Top View", fontsize=14)
ax2.set_xlabel("x")
ax2.set_ylabel("y")

plt.tight_layout()
plt.show()

# --- Run Simulation (Euler-Maruyama) ---

print(f"Simulating {N_PARTICLES} particles for {n_steps} steps...")

for step in range(n_steps):
    # Calculate deterministic force (Drift)
    fx, fy = force(particles_x, particles_y, PARAMS)
    
    # Generate random noise (Diffusion)
    # Scale by sqrt(dt) strictly according to SDE theory
    noise_x = np.random.normal(0, 1, N_PARTICLES) * np.sqrt(dt)
    noise_y = np.random.normal(0, 1, N_PARTICLES) * np.sqrt(dt)
    
    # Update positions
    particles_x += fx * dt + sigma * noise_x
    particles_y += fy * dt + sigma * noise_y

# --- Visualization ---

plt.figure(figsize=(8, 6))

# Plot the Landscape Contour
# We use negative Z for shading so valleys look darker/deeper if using some colormaps,
# but here standard viridis works well.
contour = plt.contourf(X, Y, Z, levels=25, cmap='viridis', alpha=0.6)
plt.colorbar(contour, label='Potential($\phi$)')

# Plot the Particles
# We plot them as red dots with black edges for visibility
plt.scatter(particles_x, particles_y, color='red', s=15, alpha=0.7, edgecolors='black', label='Particles')

# Mark the bifurcation line
plt.axhline(PARAMS['a'], color='white', linestyle='--', label='Bifurcation (y=0)')

plt.title(f"Particle Distribution at T={T_TOTAL} (Sigma={sigma})")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Simulating 1000 particles for 200 steps...

# %%
import ipywidgets as widgets  # Import the Jupyter-native widgets
from IPython.display import display

# Initialize
p_x = np.random.normal(x0, dx, N_PARTICLES)
p_y = np.random.normal(y0, dy, N_PARTICLES)

# History arrays
history_x = np.zeros((n_steps, N_PARTICLES))
history_y = np.zeros((n_steps, N_PARTICLES))

for i in range(n_steps):
    history_x[i] = p_x
    history_y[i] = p_y
    fx, fy = force(p_x, p_y, PARAMS)
    noise_x = np.random.normal(0, 1, N_PARTICLES) * np.sqrt(dt)
    noise_y = np.random.normal(0, 1, N_PARTICLES) * np.sqrt(dt)
    p_x += fx * dt + sigma * noise_x
    p_y += fy * dt + sigma * noise_y

# --- Visualization with Interactive Slider ---
def plot_frame(step_index):
    """
    Renders a single frame.
    Note: We create a new figure every time because 'blitting' (updating points)
    is complex to set up in VS Code without installing extra extensions like ipympl.
    """
    # Create a figure
    fig, ax = plt.subplots(figsize=(8, 8))
    
    # Plot Background
    ax.contourf(X, Y, Z, levels=25, cmap='viridis', alpha=0.6)
    ax.axhline(PARAMS['a'], color='white', linestyle='--', alpha=0.5, label='Bifurcation')
    
    # Plot Particles
    current_x = history_x[step_index]
    current_y = history_y[step_index]
    ax.scatter(current_x, current_y, c='red', s=15, edgecolors='black', alpha=0.8)
    
    # Labels
    ax.set_title(f"Time: {step_index * dt:.2f} / {T_TOTAL:.2f}")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    
    plt.show() 

# 1. Create the interactive widget object.
ui = widgets.interactive(
    plot_frame, 
    step_index=widgets.IntSlider(
        min=0, 
        max=n_steps-1, 
        step=5,           
        value=0, 
        description='Time Step',
        continuous_update=False # Prevents lagging while dragging
    )
)

# 2. Display the UI object explicitly.
display(ui)
# Out:
# interactive(children=(IntSlider(value=0, continuous_update=False, description='Time Step', max=199, step=5), O…

# %%
# MMD Parameter Inference

# 1. Generate Fake "Real Cell Data" (Target)
target_params = PARAMS.copy()

# Helper function to run sim and get just coordinates
def get_sim_data(p, steps=200, seed=None):
    # Set the random seed if provided
    if seed is not None:
        np.random.seed(seed)
        
    px = np.random.normal(x0, dx, N_PARTICLES)
    py = np.random.normal(y0, dy, N_PARTICLES)
    sq_dt = np.sqrt(dt)
    
    for _ in range(steps):
        fx, fy = force(px, py, p)
        px += fx * dt + sigma * np.random.normal(0, 1, N_PARTICLES) * sq_dt
        py += fy * dt + sigma * np.random.normal(0, 1, N_PARTICLES) * sq_dt
    return np.column_stack((px, py))

target_data = get_sim_data(target_params) # Shape: (N, 2)


# 2. Compact MMD Loss Function
def mmd_loss(x, y, bandwidth=1.5):
    """
    Calculates MMD squared: E[K(x,x)] + E[K(y,y)] - 2E[K(x,y)]
    """
    def k_mean(a, b):
        # 1. Expand dims for broadcasting: (N, 1, 2) - (1, M, 2)
        diff = a[:, None, :] - b[None, :, :]
        # 2. Squared Euclidean distance
        dist_sq = np.sum(diff**2, axis=-1)
        # 3. Gaussian Kernel & Mean
        return np.exp(-dist_sq / (2 * bandwidth**2)).mean()

    # MMD Formula
    return k_mean(x, x) + k_mean(y, y) - 2 * k_mean(x, y)


# 3. Generate Initial Guess and Run Gradient Descent

current_params = {'a':0, 'b':0.2, 'c':2, 'd':0.1 }

# Learning Rate (Should be tuned based on the scale of gradients. Same for c and d?)
lr_c = 2 
lr_d = 0.1 

print(f"Target c: {target_params['c']}, Start c: {current_params['c']}")
print(f"Target d: {target_params['d']}, Start d: {current_params['d']}")

epsilon = 0.001

for i in range(100): 
    
    # 1. Loss
    base_data = get_sim_data(current_params, steps=n_steps, seed=42)  # Fix seed for fair comparison
    base_loss = mmd_loss(base_data, target_data)
    
    # 2. Slope for c
    test_params_c = current_params.copy()
    test_params_c['c'] += epsilon 
    
    test_data_c = get_sim_data(test_params_c, steps=n_steps, seed=42)  # Fix seed for fair comparison 
    test_loss_c = mmd_loss(test_data_c, target_data)
    
    grad_c = (test_loss_c - base_loss) / epsilon
    
    # 3. Slope for d
    test_params_d = current_params.copy()
    test_params_d['d'] += epsilon
    
    test_data_d = get_sim_data(test_params_d, steps=n_steps, seed=42)  # Fix seed for fair comparison
    test_loss_d = mmd_loss(test_data_d, target_data)
    
    grad_d = (test_loss_d - base_loss) / epsilon 
    
    # 4. Update
    current_params['c'] -= lr_c * grad_c
    current_params['d'] -= lr_d * grad_d

    # Apply physical constraints
    if current_params['d'] < 0.001:
        current_params['d'] = 0.001
        
    if current_params['c'] < 0.001:
        current_params['c'] = 0.001

    # Cutoff condition (could switch to grad_c or grad_d?)
    if base_loss < 0.001:
        break
    
    print(f"Iter {i}: Loss={base_loss:.5f}")
    print(f"    Grad c={grad_c:.4f} -> Update c to {current_params['c']:.3f}")
    print(f"    Grad d={grad_d:.4f} -> Update d to {current_params['d']:.4f}")

print(f"Final Estimated c: {current_params['c']:.3f} (True: {target_params['c']})")
print(f"Final Estimated d: {current_params['d']:.3f} (True: {target_params['d']})")
# Out:
# Target c: 3, Start c: 2
# Target d: 0.2, Start d: 0.1
# Iter 0: Loss=0.01823
#     Grad c=-0.0066 -> Update c to 2.013
#     Grad d=-0.4005 -> Update d to 0.1400
# Iter 1: Loss=0.02376
#     Grad c=-0.1252 -> Update c to 2.264
#     Grad d=0.5679 -> Update d to 0.0833
# Iter 2: Loss=0.07123
#     Grad c=0.1916 -> Update c to 1.881
#     Grad d=-2.9539 -> Update d to 0.3786
# Iter 3: Loss=0.25814
#     Grad c=-0.2754 -> Update c to 2.431
#     Grad d=0.7101 -> Update d to 0.3076
# Iter 4: Loss=0.09361
#     Grad c=-0.1322 -> Update c to 2.696
#     Grad d=0.7492 -> Update d to 0.2327
# Iter 5: Loss=0.01882
#     Grad c=-0.0545 -> Update c to 2.805
#     Grad d=0.5066 -> Update d to 0.1821
# Iter 6: Loss=0.00182
#     Grad c=0.0012 -> Update c to 2.802
#     Grad d=-0.0413 -> Update d to 0.1862
# Iter 7: Loss=0.00176
#     Grad c=-0.0034 -> Update c to 2.809
#     Grad d=0.0209 -> Update d to 0.1841
# Iter 8: Loss=0.00175
#     Grad c=-0.0006 -> Update c to 2.810
#     Grad d=-0.0159 -> Update d to 0.1857
# Iter 9: Loss=0.00173
#     Grad c=-0.0022 -> Update c to 2.815
#     Grad d=0.0055 -> Update d to 0.1851
# Iter 10: Loss=0.00173
#     Grad c=-0.0012 -> Update c to 2.817
#     Grad d=-0.0068 -> Update d to 0.1858
# Iter 11: Loss=0.00172
#     Grad c=-0.0017 -> Update c to 2.821
#     Grad d=0.0003 -> Update d to 0.1858
# Iter 12: Loss=0.00171
#     Grad c=-0.0014 -> Update c to 2.823
#     Grad d=-0.0037 -> Update d to 0.1861
# Iter 13: Loss=0.00170
#     Grad c=-0.0015 -> Update c to 2.826
#     Grad d=-0.0013 -> Update d to 0.1863
# Iter 14: Loss=0.00170
#     Grad c=-0.0014 -> Update c to 2.829
#     Grad d=-0.0026 -> Update d to 0.1865
# Iter 15: Loss=0.00169
#     Grad c=-0.0014 -> Update c to 2.832
#     Grad d=-0.0018 -> Update d to 0.1867
# Iter 16: Loss=0.00169
#     Grad c=-0.0014 -> Update c to 2.835
#     Grad d=-0.0022 -> Update d to 0.1869
# Iter 17: Loss=0.00168
#     Grad c=-0.0013 -> Update c to 2.837
#     Grad d=-0.0019 -> Update d to 0.1871
# Iter 18: Loss=0.00168
#     Grad c=-0.0013 -> Update c to 2.840
#     Grad d=-0.0020 -> Update d to 0.1873
# Iter 19: Loss=0.00167
#     Grad c=-0.0013 -> Update c to 2.843
#     Grad d=-0.0019 -> Update d to 0.1875
# Iter 20: Loss=0.00167
#     Grad c=-0.0013 -> Update c to 2.845
#     Grad d=-0.0019 -> Update d to 0.1877
# Iter 21: Loss=0.00166
#     Grad c=-0.0012 -> Update c to 2.848
#     Grad d=-0.0018 -> Update d to 0.1879
# Iter 22: Loss=0.00166
#     Grad c=-0.0012 -> Update c to 2.850
#     Grad d=-0.0018 -> Update d to 0.1881
# Iter 23: Loss=0.00165
#     Grad c=-0.0012 -> Update c to 2.852
#     Grad d=-0.0017 -> Update d to 0.1882
# Iter 24: Loss=0.00165
#     Grad c=-0.0012 -> Update c to 2.855
#     Grad d=-0.0017 -> Update d to 0.1884
# Iter 25: Loss=0.00164
#     Grad c=-0.0011 -> Update c to 2.857
#     Grad d=-0.0017 -> Update d to 0.1886
# Iter 26: Loss=0.00164
#     Grad c=-0.0011 -> Update c to 2.859
#     Grad d=-0.0016 -> Update d to 0.1887
# Iter 27: Loss=0.00163
#     Grad c=-0.0011 -> Update c to 2.862
#     Grad d=-0.0016 -> Update d to 0.1889
# Iter 28: Loss=0.00163
#     Grad c=-0.0011 -> Update c to 2.864
#     Grad d=-0.0016 -> Update d to 0.1890
# Iter 29: Loss=0.00163
#     Grad c=-0.0011 -> Update c to 2.866
#     Grad d=-0.0015 -> Update d to 0.1892
# Iter 30: Loss=0.00162
#     Grad c=-0.0010 -> Update c to 2.868
#     Grad d=-0.0015 -> Update d to 0.1893
# Iter 31: Loss=0.00162
#     Grad c=-0.0010 -> Update c to 2.870
#     Grad d=-0.0015 -> Update d to 0.1895
# Iter 32: Loss=0.00162
#     Grad c=-0.0010 -> Update c to 2.872
#     Grad d=-0.0015 -> Update d to 0.1896
# Iter 33: Loss=0.00161
#     Grad c=-0.0010 -> Update c to 2.874
#     Grad d=-0.0014 -> Update d to 0.1898
# Iter 34: Loss=0.00161
#     Grad c=-0.0010 -> Update c to 2.876
#     Grad d=-0.0014 -> Update d to 0.1899
# Iter 35: Loss=0.00161
#     Grad c=-0.0009 -> Update c to 2.878
#     Grad d=-0.0014 -> Update d to 0.1901
# Iter 36: Loss=0.00160
#     Grad c=-0.0009 -> Update c to 2.880
#     Grad d=-0.0013 -> Update d to 0.1902
# Iter 37: Loss=0.00160
#     Grad c=-0.0009 -> Update c to 2.881
#     Grad d=-0.0013 -> Update d to 0.1903
# Iter 38: Loss=0.00160
#     Grad c=-0.0009 -> Update c to 2.883
#     Grad d=-0.0013 -> Update d to 0.1905
# Iter 39: Loss=0.00160
#     Grad c=-0.0009 -> Update c to 2.885
#     Grad d=-0.0013 -> Update d to 0.1906
# Iter 40: Loss=0.00159
#     Grad c=-0.0009 -> Update c to 2.887
#     Grad d=-0.0012 -> Update d to 0.1907
# Iter 41: Loss=0.00159
#     Grad c=-0.0009 -> Update c to 2.888
#     Grad d=-0.0012 -> Update d to 0.1908
# Iter 42: Loss=0.00159
#     Grad c=-0.0008 -> Update c to 2.890
#     Grad d=-0.0012 -> Update d to 0.1909
# Iter 43: Loss=0.00159
#     Grad c=-0.0008 -> Update c to 2.892
#     Grad d=-0.0012 -> Update d to 0.1911
# Iter 44: Loss=0.00158
#     Grad c=-0.0008 -> Update c to 2.893
#     Grad d=-0.0012 -> Update d to 0.1912
# Iter 45: Loss=0.00158
#     Grad c=-0.0008 -> Update c to 2.895
#     Grad d=-0.0011 -> Update d to 0.1913
# Iter 46: Loss=0.00158
#     Grad c=-0.0008 -> Update c to 2.896
#     Grad d=-0.0011 -> Update d to 0.1914
# Iter 47: Loss=0.00158
#     Grad c=-0.0008 -> Update c to 2.898
#     Grad d=-0.0011 -> Update d to 0.1915
# Iter 48: Loss=0.00157
#     Grad c=-0.0008 -> Update c to 2.900
#     Grad d=-0.0011 -> Update d to 0.1916
# Iter 49: Loss=0.00157
#     Grad c=-0.0007 -> Update c to 2.901
#     Grad d=-0.0011 -> Update d to 0.1917
# Iter 50: Loss=0.00157
#     Grad c=-0.0007 -> Update c to 2.902
#     Grad d=-0.0010 -> Update d to 0.1918
# Iter 51: Loss=0.00157
#     Grad c=-0.0007 -> Update c to 2.904
#     Grad d=-0.0010 -> Update d to 0.1919
# Iter 52: Loss=0.00157
#     Grad c=-0.0007 -> Update c to 2.905
#     Grad d=-0.0010 -> Update d to 0.1920
# Iter 53: Loss=0.00156
#     Grad c=-0.0007 -> Update c to 2.907
#     Grad d=-0.0010 -> Update d to 0.1921
# Iter 54: Loss=0.00156
#     Grad c=-0.0007 -> Update c to 2.908
#     Grad d=-0.0010 -> Update d to 0.1922
# Iter 55: Loss=0.00156
#     Grad c=-0.0007 -> Update c to 2.909
#     Grad d=-0.0009 -> Update d to 0.1923
# Iter 56: Loss=0.00156
#     Grad c=-0.0007 -> Update c to 2.911
#     Grad d=-0.0009 -> Update d to 0.1924
# Iter 57: Loss=0.00156
#     Grad c=-0.0006 -> Update c to 2.912
#     Grad d=-0.0009 -> Update d to 0.1925
# Iter 58: Loss=0.00156
#     Grad c=-0.0006 -> Update c to 2.913
#     Grad d=-0.0009 -> Update d to 0.1926
# Iter 59: Loss=0.00156
#     Grad c=-0.0006 -> Update c to 2.914
#     Grad d=-0.0009 -> Update d to 0.1927
# Iter 60: Loss=0.00155
#     Grad c=-0.0006 -> Update c to 2.916
#     Grad d=-0.0009 -> Update d to 0.1928
# Iter 61: Loss=0.00155
#     Grad c=-0.0006 -> Update c to 2.917
#     Grad d=-0.0009 -> Update d to 0.1929
# Iter 62: Loss=0.00155
#     Grad c=-0.0006 -> Update c to 2.918
#     Grad d=-0.0008 -> Update d to 0.1929
# Iter 63: Loss=0.00155
#     Grad c=-0.0006 -> Update c to 2.919
#     Grad d=-0.0008 -> Update d to 0.1930
# Iter 64: Loss=0.00155
#     Grad c=-0.0006 -> Update c to 2.920
#     Grad d=-0.0008 -> Update d to 0.1931
# Iter 65: Loss=0.00155
#     Grad c=-0.0006 -> Update c to 2.921
#     Grad d=-0.0008 -> Update d to 0.1932
# Iter 66: Loss=0.00155
#     Grad c=-0.0006 -> Update c to 2.923
#     Grad d=-0.0008 -> Update d to 0.1933
# Iter 67: Loss=0.00154
#     Grad c=-0.0005 -> Update c to 2.924
#     Grad d=-0.0008 -> Update d to 0.1933
# Iter 68: Loss=0.00154
#     Grad c=-0.0005 -> Update c to 2.925
#     Grad d=-0.0008 -> Update d to 0.1934
# Iter 69: Loss=0.00154
#     Grad c=-0.0005 -> Update c to 2.926
#     Grad d=-0.0007 -> Update d to 0.1935
# Iter 70: Loss=0.00154
#     Grad c=-0.0005 -> Update c to 2.927
#     Grad d=-0.0007 -> Update d to 0.1936
# Iter 71: Loss=0.00154
#     Grad c=-0.0005 -> Update c to 2.928
#     Grad d=-0.0007 -> Update d to 0.1936
# Iter 72: Loss=0.00154
#     Grad c=-0.0005 -> Update c to 2.929
#     Grad d=-0.0007 -> Update d to 0.1937
# Iter 73: Loss=0.00154
#     Grad c=-0.0005 -> Update c to 2.930
#     Grad d=-0.0007 -> Update d to 0.1938
# Iter 74: Loss=0.00154
#     Grad c=-0.0005 -> Update c to 2.931
#     Grad d=-0.0007 -> Update d to 0.1938
# Iter 75: Loss=0.00154
#     Grad c=-0.0005 -> Update c to 2.932
#     Grad d=-0.0007 -> Update d to 0.1939
# Iter 76: Loss=0.00153
#     Grad c=-0.0005 -> Update c to 2.933
#     Grad d=-0.0007 -> Update d to 0.1940
# Iter 77: Loss=0.00153
#     Grad c=-0.0005 -> Update c to 2.934
#     Grad d=-0.0007 -> Update d to 0.1940
# Iter 78: Loss=0.00153
#     Grad c=-0.0005 -> Update c to 2.935
#     Grad d=-0.0006 -> Update d to 0.1941
# Iter 79: Loss=0.00153
#     Grad c=-0.0004 -> Update c to 2.935
#     Grad d=-0.0006 -> Update d to 0.1942
# Iter 80: Loss=0.00153
#     Grad c=-0.0004 -> Update c to 2.936
#     Grad d=-0.0006 -> Update d to 0.1942
# Iter 81: Loss=0.00153
#     Grad c=-0.0004 -> Update c to 2.937
#     Grad d=-0.0006 -> Update d to 0.1943
# Iter 82: Loss=0.00153
#     Grad c=-0.0004 -> Update c to 2.938
#     Grad d=-0.0006 -> Update d to 0.1944
# Iter 83: Loss=0.00153
#     Grad c=-0.0004 -> Update c to 2.939
#     Grad d=-0.0006 -> Update d to 0.1944
# Iter 84: Loss=0.00153
#     Grad c=-0.0004 -> Update c to 2.940
#     Grad d=-0.0006 -> Update d to 0.1945
# Iter 85: Loss=0.00153
#     Grad c=-0.0004 -> Update c to 2.940
#     Grad d=-0.0006 -> Update d to 0.1945
# Iter 86: Loss=0.00153
#     Grad c=-0.0004 -> Update c to 2.941
#     Grad d=-0.0006 -> Update d to 0.1946
# Iter 87: Loss=0.00153
#     Grad c=-0.0004 -> Update c to 2.942
#     Grad d=-0.0006 -> Update d to 0.1946
# Iter 88: Loss=0.00152
#     Grad c=-0.0004 -> Update c to 2.943
#     Grad d=-0.0005 -> Update d to 0.1947
# Iter 89: Loss=0.00152
#     Grad c=-0.0004 -> Update c to 2.944
#     Grad d=-0.0005 -> Update d to 0.1948
# Iter 90: Loss=0.00152
#     Grad c=-0.0004 -> Update c to 2.944
#     Grad d=-0.0005 -> Update d to 0.1948
# Iter 91: Loss=0.00152
#     Grad c=-0.0004 -> Update c to 2.945
#     Grad d=-0.0005 -> Update d to 0.1949
# Iter 92: Loss=0.00152
#     Grad c=-0.0004 -> Update c to 2.946
#     Grad d=-0.0005 -> Update d to 0.1949
# Iter 93: Loss=0.00152
#     Grad c=-0.0004 -> Update c to 2.947
#     Grad d=-0.0005 -> Update d to 0.1950
# Iter 94: Loss=0.00152
#     Grad c=-0.0004 -> Update c to 2.947
#     Grad d=-0.0005 -> Update d to 0.1950
# Iter 95: Loss=0.00152
#     Grad c=-0.0003 -> Update c to 2.948
#     Grad d=-0.0005 -> Update d to 0.1951
# Iter 96: Loss=0.00152
#     Grad c=-0.0003 -> Update c to 2.949
#     Grad d=-0.0005 -> Update d to 0.1951
# Iter 97: Loss=0.00152
#     Grad c=-0.0003 -> Update c to 2.949
#     Grad d=-0.0005 -> Update d to 0.1952
# Iter 98: Loss=0.00152
#     Grad c=-0.0003 -> Update c to 2.950
#     Grad d=-0.0005 -> Update d to 0.1952
# Iter 99: Loss=0.00152
#     Grad c=-0.0003 -> Update c to 2.951
#     Grad d=-0.0005 -> Update d to 0.1952
# Final Estimated c: 2.951 (True: 3)
# Final Estimated d: 0.195 (True: 0.2)

# %%
# --- Another Method ---

import torch
from scipy.optimize import minimize
import seaborn as sns

# --- 1. PyTorch Setup ---
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Running on: {device}")

DT_T = torch.tensor(dt, device=device)
SQRT_DT_T = torch.sqrt(DT_T)

def simulate_torch(params_list, seed=None):
    if seed is not None:
        torch.manual_seed(seed)
    
    c, d = params_list
    a = PARAMS['a']
    b = PARAMS['b']

    _x0 = x0[0] if isinstance(x0, list) else x0
    _y0 = y0[0] if isinstance(y0, list) else y0
    _dx = dx[0] if isinstance(dx, list) else dx
    _dy = dy[0] if isinstance(dy, list) else dy

    x = torch.randn(N_PARTICLES, device=device) * _dx + _x0
    y = torch.randn(N_PARTICLES, device=device) * _dy + _y0

    for _ in range(n_steps):
        fx = 2 * (y - a) * x - 4 * b * (x**3)
        fy = (x**2) + c - 4 * d * (y**3)

        noise_x = torch.randn(N_PARTICLES, device=device)
        noise_y = torch.randn(N_PARTICLES, device=device)

        x += fx * DT_T + sigma * noise_x * SQRT_DT_T
        y += fy * DT_T + sigma * noise_y * SQRT_DT_T

    return torch.stack((x, y), dim=1)

def calc_multiscale_mmd(x, y, bandwidths=[0.5, 2.0, 5.0]):
    xx_dist = torch.cdist(x, x)
    yy_dist = torch.cdist(y, y)
    xy_dist = torch.cdist(x, y)
    total_loss = 0.0
    for bw in bandwidths:
        gamma = 1.0 / (2 * bw**2)
        k_xx = torch.exp(-gamma * xx_dist**2).mean()
        k_yy = torch.exp(-gamma * yy_dist**2).mean()
        k_xy = torch.exp(-gamma * xy_dist**2).mean()
        total_loss += (k_xx + k_yy - 2 * k_xy)
    return total_loss

# --- 2. Generate Ground Truth ---
print(f"Generating target data (True c={target_params['c']}, d={target_params['d']})...")
target_data = simulate_torch([target_params['c'], target_params['d']], seed=42)

# --- 3. Grid Search & Visualization ---

c_range = np.linspace(0, 5.0, 40)  # try 20 values for c
d_range = np.linspace(0, 0.3, 40) # try 20 values for d

loss_grid = np.zeros((len(d_range), len(c_range)))
best_loss_grid = float('inf')
best_params_grid = [0, 0]

# scan the grid
for i, d_val in enumerate(d_range):
    for j, c_val in enumerate(c_range):
        # seed=42
        sim = simulate_torch([c_val, d_val], seed=42)
        loss = calc_multiscale_mmd(sim, target_data).item() * 100
        
        loss_grid[i, j] = loss
        
        if loss < best_loss_grid:
            best_loss_grid = loss
            best_params_grid = [c_val, d_val]

print(f"Grid Search Best: c={best_params_grid[0]:.3f}, d={best_params_grid[1]:.3f}")

# --- 4. Plot Heatmap ---
plt.figure(figsize=(10, 8))
ax = sns.heatmap(loss_grid, xticklabels=np.round(c_range, 2), yticklabels=np.round(d_range, 3), cmap="viridis_r", annot=False)
ax.invert_yaxis() 
plt.xlabel("Parameter c (Drive)")
plt.ylabel("Parameter d (Wall Steepness)")
plt.title(f"MMD Loss Landscape\nTrue Params at c={target_params['c']}, d={target_params['d']}")
# mark the best point found by grid search
plt.scatter(np.searchsorted(c_range, best_params_grid[0]), np.searchsorted(d_range, best_params_grid[1]), c='red', s=100, marker='*', label='Grid Minimum')
plt.show()

# --- 5. Fine-Tuning with Nelder-Mead ---

print(f"Refining from Grid Best: {best_params_grid}...")

def objective(p):
    c_val, d_val = p
    if d_val < 0.001 or c_val < 0: return 1e6
    sim_data = simulate_torch([c_val, d_val], seed=42)
    return calc_multiscale_mmd(sim_data, target_data).item() * 100

res = minimize(
    objective, 
    best_params_grid, # <--- key: from the best point
    method='Nelder-Mead', 
    options={'disp': True, 'maxiter': 50, 'xatol': 1e-4}
)

print(f"Final Result:")
print(f"True:      c={target_params['c']}, d={target_params['d']}")
print(f"Estimated: c={res.x[0]:.3f}, d={res.x[1]:.3f}")
# Out:
# Running on: cpu
# Generating target data (True c=3, d=0.2)...
# Grid Search Best: c=2.949, d=0.200
# Refining from Grid Best: [np.float64(2.9487179487179485), np.float64(0.19999999999999998)]...
# Optimization terminated successfully.
#          Current function value: -0.000018
#          Iterations: 28
#          Function evaluations: 62
# Final Result:
# True:      c=3, d=0.2
# Estimated: c=3.001, d=0.200
